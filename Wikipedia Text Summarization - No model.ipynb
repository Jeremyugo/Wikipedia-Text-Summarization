# %% [markdown]
# ## Text Summarization

# %%
import requests
from bs4 import BeautifulSoup
import re
import nltk
from string import punctuation
from nltk.corpus import stopwords
from heapq import nlargest

# %%
content = requests.get("https://en.wikipedia.org/wiki/Sekiro:_Shadows_Die_Twice").text

# %%
print(content[:1000])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Sekiro: Shadows Die Twice - Wikipedia</title>
# <script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"ce4a99ff-8a7e-4136-b8f2-3de2b7842395","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Sekiro:_Shadows_Die_Twice","wgTitle":"Sekiro: Shadows Die Twice","wgCurRevisionId":1089622715,"wgRevisionId":1089622715,"wgArticleId":57651025,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles containing Japanese-language text","CS1 Japanese-language sources (ja)","CS1 uses Chinese-language script (

# %%
article = BeautifulSoup(content, 'lxml')

# %%
article_content = ""
for paragraph in article.find_all('p'):
    article_content += paragraph.text

# %%
print(article_content)
# Out:
# Sekiro: Shadows Die Twice[a] is a 2019 action-adventure game developed by FromSoftware and published by Activision. The game follows a shinobi known as Wolf as he attempts to take revenge on a samurai clan who attacked him and kidnapped his lord. It was released for Microsoft Windows, PlayStation 4, and Xbox One in March 2019 and for Stadia in October 2020.
# Gameplay is focused on stealth, exploration, and combat, with a particular emphasis on boss battles. The game takes place in a fictionalized Japan during the Sengoku period and makes strong references to Buddhist mythology and philosophy. While making the game, lead director Hidetaka Miyazaki wanted to create a new intellectual property (IP) that marked a departure from the Souls series of games also made by FromSoftware. The developers looked to games such as The Mysterious Murasame Castle and the Tenchu series for inspiration.
# Sekiro was praised by critics, who complimented its gameplay and setting, and compared it to the Souls games, although opinions on its difficulty were mixed. It was nominated for various awards and won several, including The Game Award for Game of the Year. The game sold over five million copies by July 2020.
# Sekiro: Shadows Die Twice is an action-adventure game played from a third-person view.[1][2][3][4] Compared to FromSoftware's Souls series, the game features fewer role-playing elements, lacking character creation and the ability to level up a variety of stats, as well as having no multiplayer elements.[3][4][5][6] It does, however, include gear upgrading, a skill tree, and limited ability customization. Rather than attacking to whittle an enemy's health points, combat in Sekiro revolves around using a katana to attack their posture and balance instead, which eventually leads to an opening that allows for a single killing blow.[3][7]
# The game also features stealth elements, allowing players to instantly eliminate some enemies if they can get in range undetected.[3] In addition, the player character can use various tools to assist with combat and exploration, such as a grappling hook.[3] If the player character dies, they have the option of being revived on the spot if they have resurrection power, which is restored by defeating enemies, instead of respawning at earlier checkpoints.[3]
# Following the Sengoku period, Isshin Ashina seized control of the land of Ashina.[1] During this time, a nameless orphan is adopted by the wandering shinobi known as "Owl", who named the boy "Wolf", and trained him in the ways of the shinobi. Two decades later, Ashina is on the brink of collapse due to the now elderly Isshin falling ill and the Interior Ministry, a group set on unifying Japan, steadily closing in. Desperate to save his clan, Isshin's adoptive grandson Genichiro seeks the immortal "Divine Heir" Kuro in hopes of using the "Dragon Heritage" in his blood to create an immortal army. Wolf, now a full-fledged shinobi and Kuro's personal bodyguard, fights Genichiro but loses the duel along with his left arm while Genichiro takes the boy. However, being immortal himself, Wolf survives and is found by a retired shinobi known as the "Sculpter", who nurses him
# back to health and gifts him a Shinobi Prosthetic.[3][8][9]
# To rescue Kuro, Wolf assaults Ashina Castle whilst being forced to confront his own past: three years ago, Kuro's birthplace, the Hirata estate, was raided by bandits led by Wolf's former teacher, Lady Butterfly, who was attempting to kidnap Kuro. While Wolf was able to defeat her, he was then stabbed in the back by an unknown assailant but survived thanks to Kuro making him immortal through the Dragon's Heritage. Back in the present, Wolf once again confronts Genichiro and this time, defeats him. However, Genichiro survives by drinking an artificial replication of the Dragon Heritage known as the "Rejuvenating Waters", and flees. Kuro then asks Wolf to perform the "Immortal Severance" ritual, which would result in Kuro's death and prevent anyone from fighting over his immortality. Wolf reluctantly agrees to help and sets out to collect the necessary materials for the ritual. Wolf's quest also leads him to cross paths with Isshin, who gives him a new name: "Sekiro", the "one-armed wolf".
# After collecting all the components for the ritual, Sekiro is confronted by Owl, who was thought to have been killed during the raid on Hirata and revealed to be the one who back-stabbed Sekiro back then. Owl reveals he also seeks the Dragon Heritage and orders Sekiro to renounce his loyalty to Kuro. If Sekiro sides with Owl, he is forced to fight Isshin's doctor, Emma, and Isshin himself. Upon defeating them, Sekiro proceeds to betray Owl while Kuro realizes he has been corrupted by bloodlust, resulting in the "Shura" ending. If Kuro is chosen, Sekiro fights and kills Owl. Sekiro then enters the Divine Realm to collect the final material for the ritual. Upon returning to Ashina, Sekiro discovers Isshin has succumbed to his illness and that the castle is under attack by the Interior Ministry. Sekiro eventually finds Kuro under attack by Genichiro, who challenges Sekiro for the Dragon Heritage, only to be defeated once again. Realizing Ashina is lost, Genichiro uses a ritual to revive Isshin in his prime so he might restore the clan, at the cost of his own life. Although he disagrees with Genichiro's methods, Isshin honors his grandson's wish and fights Sekiro.
# After defeating Isshin, there are three possible endings. Performing the "Immortal Severance" ritual results in the eponymous standard ending, where the Dragon Heritage is removed at the cost of Kuro's life. Afterward, like the Sculptor before him, Sekiro retires as a shinobi and spends the remainder of his days carving Buddha Statues. Working with Emma to find an alternative way of severing immortality results in the "Purification" ending, where Sekiro sacrifices himself instead of Kuro. The final ending, "Dragon's Homecoming", is obtained by helping a character known as the "Divine Child of the Rejuvenating Waters": Kuro's body dies, but his spirit lives on inside the Divine Child, who goes on a journey with Sekiro to return the Dragon Heritage to its origin place.
# Development of Sekiro began in late 2015 following the completion of Bloodborne's downloadable content, The Old Hunters.[10] The game was revealed via a teaser trailer at The Game Awards 2017 in December, showing the tagline "Shadows Die Twice".[11] The game's full title was revealed to be Sekiro: Shadows Die Twice during Microsoft's press conference at E3 2018. It was directed by Hidetaka Miyazaki of the Japanese development studio FromSoftware, best known for creating the Souls series and Bloodborne.[12] The game was published by Activision worldwide, with FromSoftware self-publishing it in Japan and Cube Game publishing in the Asia-Pacific region.[13][14] Sekiro's soundtrack was composed by Yuka Kitamura,[15] with some contributions from Noriyuki Asakura. The game was released for PlayStation 4, Windows, and Xbox One on 22 March 2019.[16] A collectors edition was also released the same day, and included a steelbook case, a figurine of the protagonist, an art book, a physical map of the game's world, a download code for the soundtrack, and in-game coin replicas.[16] A port for Stadia was released in late 2020.[17]
# Sekiro draws inspiration from the Tenchu series of stealth-action games that were partially developed and published by FromSoftware.[18] The team initially considered developing the game as a sequel to Tenchu. However, as that series had already been shaped by several different studios before they obtained the rights to it, they instead opted to take the project in a different direction.[10] Miyazaki intended the combat changes to capture the feel of "swords clashing", with fighters trying to create an opening to deliver the fatal strike.[3] He and the team also created the game to be an entirely single-player experience, as they believed multiplayer to have limitations they wanted to avoid.[6]
# The word "sekirō" (隻狼) is a contraction of "sekiwan no ōkami" (隻腕の狼), which translates as "one-armed wolf."[19] The subtitle "Shadows Die Twice" was initially meant to be used as a slogan for the teaser trailer until Activision requested it be kept for the final name.[3][20] Despite the game taking place during the Sengoku period of real-world Japanese history, no historical people or locations are featured in the game.[21] On 31 October 2020, a free update was released that added new content to the game, such as new cosmetics for Wolf and a boss rush game mode.[22]
# According to review aggregator Metacritic, Sekiro received "universal acclaim" for the PlayStation 4 and Xbox One versions, and "generally favorable" reviews for the Windows version.[23][24][25] Many critics praised the game's combat for departing from the typical style of FromSoftware's other similar games. In a review for Destructoid, Chris Carter described open combat as "akin to a waltz" and praised the variety of ways the combat could be approached, writing that players had more choices than in Dark Souls or Bloodborne.[26] Brandin Tyrell from IGN praised the game's focus on "split-second swordsmanship", and despite the fact that "to any Souls veteran, Sekiro's timing-based lock-on combat of strikes and slashes is familiar", the game's "sense of safety" caused the combat to feel "refreshing and new".[33] PC Gamer journalist Tom Senior called the combat "beautiful" and praised the posture system, writing that "instead of chipping down health bars until the enemy keels over, you overwhelm their posture bar with strikes and perfect parries until an opening appears, and then finish with a deathblow".[38] He stated that the system takes "the catharsis" of beating a great boss and "focuses all that emotion into one split second". In a review for website GameSpot, Tamoor Hussain wrote that the game "rewrites the rules of engagement", stating that, while previous FromSoftware games demanded quick decision-making, Sekiro "pushes these demands further" than ever before. Reviewers also praised the resurrection mechanic, with Carter calling it "genius", and the stealth options, which gave the player freedom without descending into frustration.
# The level design was also praised. Particular emphasis was given to the increased verticality the player had due to the addition of the grappling hook and a dedicated jump button. Tyrell wrote that the grappling hook "sends ripples throughout the gameplay", writing that "where all previous Soulsborne characters felt rooted firmly to the ground as they trudged down hallways and slowly climbed ladders, Sekiro's level design has permission to be much more vertical". Carter wrote that the hook provided "a more vertical and in some cases more challenging level design from an exploration standpoint". Senior wrote that the game used "large but separate zones rather than a huge connected world", but praised the "many secrets hidden just off the critical path, often reached with the excellent grappling hook, which lets you vault between tree branches and rooftops". The levels themselves were also praised, with Hussain writing that "buildings are placed together to encourage exploration and reconnaissance, with roofs almost touching so that you can leap between them and scope out all angles", with the branching paths "creating that satisfying feeling of venturing into the unknown and then emerging into the familiar".[31]
# Reaction to the lack of online multiplayer was mixed. Several reviewers noted that this allowed the game to have a full pause button, which was praised. However, Tyrell noted that he "missed the small notes left by others in the world alerting me to imminent threats or hidden secrets, or that vague sense that danger lurks behind me in the form of an invading player" that defined the experience of playing "Soulsborne" games. He also noticed the "lack of PvP battles, which seem[ed] like a waste of the new emphasis on skill-based swordsmanship", and argued that the parrying and blocking mechanics would have suited online play.
# Similarly to other FromSoftware games, the game's high level of difficulty polarised players and journalists. Several reviewers praised the difficulty, with Senior calling it "brutal" but "spectacular". Hussain wrote that the game "punishes you for missteps" and was "suited for people of a certain temperament and with a very specific, slightly masochistic taste in games", but argued that victory was "intense" and "gratifying". Tyrell wrote that the combat had a "steep curve to mastering it" but argued it was "somewhat easier than its predecessors", while still providing the sense of being "the greatest swordsman that ever lived" after tough victories. However, several journalists found it to be too tough, with Don Rowe from The Spinoff calling it "infuriating", and writing that he was not having fun after six hours with the game.[39] Forbes journalist Dave Thier criticized FromSoftware's decision to have one set difficulty on the game, claiming this made it inaccessible to players with a lower skill level. He argued that the studio should "respect its players" and add an easier difficulty mode.[40] Several days after the game was released, modders managed to develop mods which would make the game easier by changing the speed of the player's character relative to the game.[41] James Davenport of PC Gamer said that the game's final boss was too difficult for him to beat without the help of the software.[42]
# On release day, Sekiro drew over 108,000 concurrent players on Steam, the highest for a new game launched during January–March 2019, and the third highest of any Japanese game in the platform's history, behind only Monster Hunter: World and Dark Souls III.[43][44] Later in March, it had reached over 125,000 concurrent players on Steam, making it one of the most played games on the platform at the time.[45] In its debut week, Sekiro topped both the UK and EMEAA (Europe, Middle East, Africa, Asia) charts, surpassing Tom Clancy's The Division 2.[46][47][48] In Japan, the game debuted at first with 157,548 retail copies sold in its opening weekend.[49] Within ten days of its release, over two million copies were sold worldwide, which rose to over five million by July 2020.[50][51]
# The game was nominated for and won several awards, including game of the year at The Game Awards 2019,[52] by editors of GameSpot,[53] and by fans in the 2019 Steam Awards.[54]

# %%
punctuation_ = punctuation + '\n'
stop_words = stopwords.words('english')

# %%
# Create Frequency table, excluse stopwords and punctuations

def FrequecyTable(text):
    text = nltk.word_tokenize(text)
    text = [word for word in text if word not in punctuation_ and word not in stop_words]
    table = {}
    for word in text:
        if word in table:
            table[word] += 1
        else:
            table[word] = 1
    return table

# %%
word_frequecies = FrequecyTable(article_content)
word_frequecies
# Out:
# {'Sekiro': 29,
#  'Shadows': 5,
#  'Die': 5,
#  'Twice': 5,
#  '2019': 6,
#  'action-adventure': 2,
#  'game': 38,
#  'developed': 2,
#  'FromSoftware': 10,
#  'published': 3,
#  'Activision': 3,
#  'The': 23,
#  'follows': 1,
#  'shinobi': 6,
#  'known': 6,
#  'Wolf': 12,
#  'attempts': 1,
#  'take': 2,
#  'revenge': 1,
#  'samurai': 1,
#  'clan': 3,
#  'attacked': 1,
#  'kidnapped': 1,
#  'lord': 1,
#  'It': 4,
#  'released': 6,
#  'Microsoft': 2,
#  'Windows': 3,
#  'PlayStation': 3,
#  '4': 5,
#  'Xbox': 3,
#  'One': 3,
#  'March': 3,
#  'Stadia': 2,
#  'October': 2,
#  '2020': 5,
#  'Gameplay': 1,
#  'focused': 1,
#  'stealth': 3,
#  'exploration': 4,
#  'combat': 11,
#  'particular': 1,
#  'emphasis': 3,
#  'boss': 4,
#  'battles': 2,
#  'takes': 3,
#  'place': 3,
#  'fictionalized': 1,
#  'Japan': 4,
#  'Sengoku': 3,
#  'period': 3,
#  'makes': 1,
#  'strong': 1,
#  'references': 1,
#  'Buddhist': 1,
#  'mythology': 1,
#  'philosophy': 1,
#  'While': 2,
#  'making': 3,
#  'lead': 1,
#  'director': 1,
#  'Hidetaka': 2,
#  'Miyazaki': 3,
#  'wanted': 2,
#  'create': 3,
#  'new': 7,
#  'intellectual': 1,
#  'property': 1,
#  'IP': 1,
#  'marked': 1,
#  'departure': 1,
#  'Souls': 7,
#  'series': 6,
#  'games': 10,
#  'also': 10,
#  'made': 2,
#  'developers': 1,
#  'looked': 1,
#  'Mysterious': 1,
#  'Murasame': 1,
#  'Castle': 2,
#  'Tenchu': 3,
#  'inspiration': 2,
#  'praised': 11,
#  'critics': 2,
#  'complimented': 1,
#  'gameplay': 2,
#  'setting': 1,
#  'compared': 1,
#  'although': 1,
#  'opinions': 1,
#  'difficulty': 5,
#  'mixed': 2,
#  'nominated': 2,
#  'various': 2,
#  'awards': 2,
#  'several': 4,
#  'including': 2,
#  'Game': 5,
#  'Award': 1,
#  'Year': 1,
#  'sold': 3,
#  'five': 2,
#  'million': 3,
#  'copies': 3,
#  'July': 2,
#  'played': 2,
#  'third-person': 1,
#  'view': 1,
#  '1': 2,
#  '2': 2,
#  '3': 9,
#  'Compared': 1,
#  "'s": 32,
#  'features': 2,
#  'fewer': 1,
#  'role-playing': 1,
#  'elements': 3,
#  'lacking': 1,
#  'character': 5,
#  'creation': 1,
#  'ability': 2,
#  'level': 6,
#  'variety': 2,
#  'stats': 1,
#  'well': 1,
#  'multiplayer': 3,
#  '5': 1,
#  '6': 2,
#  'however': 1,
#  'include': 1,
#  'gear': 1,
#  'upgrading': 1,
#  'skill': 2,
#  'tree': 2,
#  'limited': 1,
#  'customization': 1,
#  'Rather': 1,
#  'attacking': 1,
#  'whittle': 1,
#  'enemy': 2,
#  'health': 3,
#  'points': 1,
#  'revolves': 1,
#  'around': 1,
#  'using': 2,
#  'katana': 1,
#  'attack': 3,
#  'posture': 3,
#  'balance': 1,
#  'instead': 5,
#  'eventually': 2,
#  'leads': 2,
#  'opening': 4,
#  'allows': 1,
#  'single': 1,
#  'killing': 1,
#  'blow': 1,
#  '7': 1,
#  'allowing': 1,
#  'players': 7,
#  'instantly': 1,
#  'eliminate': 1,
#  'enemies': 2,
#  'get': 1,
#  'range': 1,
#  'undetected': 1,
#  'In': 5,
#  'addition': 2,
#  'player': 6,
#  'use': 1,
#  'tools': 1,
#  'assist': 1,
#  'grappling': 4,
#  'hook': 5,
#  'If': 3,
#  'dies': 2,
#  'option': 1,
#  'revived': 1,
#  'spot': 1,
#  'resurrection': 2,
#  'power': 1,
#  'restored': 1,
#  'defeating': 3,
#  'respawning': 1,
#  'earlier': 1,
#  'checkpoints': 1,
#  'Following': 1,
#  'Isshin': 10,
#  'Ashina': 6,
#  'seized': 1,
#  'control': 1,
#  'land': 1,
#  'During': 1,
#  'time': 3,
#  'nameless': 1,
#  'orphan': 1,
#  'adopted': 1,
#  'wandering': 1,
#  '``': 56,
#  'Owl': 6,
#  "''": 54,
#  'named': 1,
#  'boy': 2,
#  'trained': 1,
#  'ways': 2,
#  'Two': 1,
#  'decades': 1,
#  'later': 1,
#  'brink': 1,
#  'collapse': 1,
#  'due': 2,
#  'elderly': 1,
#  'falling': 1,
#  'ill': 1,
#  'Interior': 2,
#  'Ministry': 2,
#  'group': 1,
#  'set': 2,
#  'unifying': 1,
#  'steadily': 1,
#  'closing': 1,
#  'Desperate': 1,
#  'save': 1,
#  'adoptive': 1,
#  'grandson': 2,
#  'Genichiro': 8,
#  'seeks': 2,
#  'immortal': 4,
#  'Divine': 4,
#  'Heir': 1,
#  'Kuro': 15,
#  'hopes': 1,
#  'Dragon': 8,
#  'Heritage': 7,
#  'blood': 1,
#  'army': 1,
#  'full-fledged': 1,
#  'personal': 1,
#  'bodyguard': 1,
#  'fights': 3,
#  'loses': 1,
#  'duel': 1,
#  'along': 1,
#  'left': 2,
#  'arm': 1,
#  'However': 5,
#  'survives': 2,
#  'found': 2,
#  'retired': 1,
#  'Sculpter': 1,
#  'nurses': 1,
#  'back': 3,
#  'gifts': 1,
#  'Shinobi': 1,
#  'Prosthetic': 1,
#  '8': 1,
#  '9': 1,
#  'To': 1,
#  'rescue': 1,
#  'assaults': 1,
#  'whilst': 1,
#  'forced': 2,
#  'confront': 1,
#  'past': 1,
#  'three': 2,
#  'years': 1,
#  'ago': 1,
#  'birthplace': 1,
#  'Hirata': 2,
#  'estate': 1,
#  'raided': 1,
#  'bandits': 1,
#  'led': 1,
#  'former': 1,
#  'teacher': 1,
#  'Lady': 1,
#  'Butterfly': 1,
#  'attempting': 1,
#  'kidnap': 1,
#  'able': 1,
#  'defeat': 1,
#  'stabbed': 1,
#  'unknown': 2,
#  'assailant': 1,
#  'survived': 1,
#  'thanks': 1,
#  'Back': 1,
#  'present': 1,
#  'confronts': 1,
#  'defeats': 1,
#  'drinking': 1,
#  'artificial': 1,
#  'replication': 1,
#  'Rejuvenating': 2,
#  'Waters': 2,
#  'flees': 1,
#  'asks': 1,
#  'perform': 1,
#  'Immortal': 2,
#  'Severance': 2,
#  'ritual': 6,
#  'would': 3,
#  'result': 1,
#  'death': 1,
#  'prevent': 1,
#  'anyone': 1,
#  'fighting': 1,
#  'immortality': 2,
#  'reluctantly': 1,
#  'agrees': 1,
#  'help': 2,
#  'sets': 1,
#  'collect': 2,
#  'necessary': 1,
#  'materials': 1,
#  'quest': 1,
#  'cross': 1,
#  'paths': 2,
#  'gives': 1,
#  'name': 2,
#  'one-armed': 2,
#  'wolf': 2,
#  'After': 2,
#  'collecting': 1,
#  'components': 1,
#  'confronted': 1,
#  'thought': 1,
#  'killed': 1,
#  'raid': 1,
#  'revealed': 3,
#  'one': 4,
#  'back-stabbed': 1,
#  'reveals': 1,
#  'orders': 1,
#  'renounce': 1,
#  'loyalty': 1,
#  'sides': 1,
#  'fight': 1,
#  'doctor': 1,
#  'Emma': 2,
#  'Upon': 2,
#  'proceeds': 1,
#  'betray': 1,
#  'realizes': 1,
#  'corrupted': 1,
#  'bloodlust': 1,
#  'resulting': 1,
#  'Shura': 1,
#  'ending': 4,
#  'chosen': 1,
#  'kills': 1,
#  'enters': 1,
#  'Realm': 1,
#  'final': 4,
#  'material': 1,
#  'returning': 1,
#  'discovers': 1,
#  'succumbed': 1,
#  'illness': 1,
#  'castle': 1,
#  'finds': 1,
#  'challenges': 1,
#  'defeated': 1,
#  'Realizing': 1,
#  'lost': 1,
#  'uses': 1,
#  'revive': 1,
#  'prime': 1,
#  'might': 1,
#  'restore': 1,
#  'cost': 2,
#  'life': 2,
#  'Although': 1,
#  'disagrees': 1,
#  'methods': 1,
#  'honors': 1,
#  'wish': 1,
#  'possible': 1,
#  'endings': 1,
#  'Performing': 1,
#  'results': 2,
#  'eponymous': 1,
#  'standard': 1,
#  'removed': 1,
#  'Afterward': 1,
#  'like': 2,
#  'Sculptor': 1,
#  'retires': 1,
#  'spends': 1,
#  'remainder': 1,
#  'days': 3,
#  'carving': 1,
#  'Buddha': 1,
#  'Statues': 1,
#  'Working': 1,
#  'find': 1,
#  'alternative': 1,
#  'way': 1,
#  'severing': 1,
#  'Purification': 1,
#  'sacrifices': 1,
#  'Homecoming': 1,
#  'obtained': 2,
#  'helping': 1,
#  'Child': 2,
#  'body': 1,
#  'spirit': 1,
#  'lives': 1,
#  'inside': 1,
#  'goes': 1,
#  'journey': 1,
#  'return': 1,
#  'origin': 1,
#  'Development': 1,
#  'began': 1,
#  'late': 2,
#  '2015': 1,
#  'following': 1,
#  'completion': 1,
#  'Bloodborne': 3,
#  'downloadable': 1,
#  'content': 2,
#  'Old': 1,
#  'Hunters': 1,
#  '10': 2,
#  'via': 1,
#  'teaser': 2,
#  'trailer': 2,
#  'Awards': 3,
#  '2017': 1,
#  'December': 1,
#  'showing': 1,
#  'tagline': 1,
#  '11': 1,
#  'full': 2,
#  'title': 1,
#  'press': 1,
#  'conference': 1,
#  'E3': 1,
#  '2018': 1,
#  'directed': 1,
#  'Japanese': 3,
#  'development': 1,
#  'studio': 2,
#  'best': 1,
#  'creating': 2,
#  '12': 1,
#  'worldwide': 2,
#  'self-publishing': 1,
#  'Cube': 1,
#  'publishing': 1,
#  'Asia-Pacific': 1,
#  'region': 1,
#  '13': 1,
#  '14': 1,
#  'soundtrack': 2,
#  'composed': 1,
#  'Yuka': 1,
#  'Kitamura': 1,
#  '15': 1,
#  'contributions': 1,
#  'Noriyuki': 1,
#  'Asakura': 1,
#  '22': 2,
#  '16': 2,
#  'A': 2,
#  'collectors': 1,
#  'edition': 1,
#  'day': 2,
#  'included': 1,
#  'steelbook': 1,
#  'case': 1,
#  'figurine': 1,
#  'protagonist': 1,
#  'art': 1,
#  'book': 1,
#  'physical': 1,
#  'map': 1,
#  'world': 3,
#  'download': 1,
#  'code': 1,
#  'in-game': 1,
#  'coin': 1,
#  'replicas': 1,
#  'port': 1,
#  '17': 1,
#  'draws': 1,
#  'stealth-action': 1,
#  'partially': 1,
#  '18': 1,
#  'team': 2,
#  'initially': 2,
#  'considered': 1,
#  'developing': 1,
#  'sequel': 1,
#  'already': 1,
#  'shaped': 1,
#  'different': 2,
#  'studios': 1,
#  'rights': 1,
#  'opted': 1,
#  'project': 1,
#  'direction': 1,
#  'intended': 1,
#  'changes': 1,
#  'capture': 1,
#  'feel': 2,
#  'swords': 1,
#  'clashing': 1,
#  'fighters': 1,
#  'trying': 1,
#  'deliver': 1,
#  'fatal': 1,
#  'strike': 1,
#  'He': 4,
#  'created': 1,
#  'entirely': 1,
#  'single-player': 1,
#  'experience': 2,
#  'believed': 1,
#  'limitations': 1,
#  'avoid': 1,
#  'word': 1,
#  'sekirō': 1,
#  '隻狼': 1,
#  'contraction': 1,
#  'sekiwan': 1,
#  'ōkami': 1,
#  '隻腕の狼': 1,
#  'translates': 1,
#  '19': 1,
#  'subtitle': 1,
#  'meant': 1,
#  'used': 2,
#  'slogan': 1,
#  'requested': 1,
#  'kept': 1,
#  '20': 1,
#  'Despite': 1,
#  'taking': 1,
#  'real-world': 1,
#  'history': 2,
#  'historical': 1,
#  'people': 2,
#  'locations': 1,
#  'featured': 1,
#  '21': 1,
#  'On': 2,
#  '31': 2,
#  'free': 1,
#  'update': 1,
#  'added': 1,
#  'cosmetics': 1,
#  'rush': 1,
#  'mode': 2,
#  'According': 1,
#  'review': 3,
#  'aggregator': 1,
#  'Metacritic': 1,
#  'received': 1,
#  'universal': 1,
#  'acclaim': 1,
#  'versions': 1,
#  'generally': 1,
#  'favorable': 1,
#  'reviews': 1,
#  'version': 1,
#  '23': 1,
#  '24': 1,
#  '25': 1,
#  'Many': 1,
#  'departing': 1,
#  'typical': 1,
#  'style': 1,
#  'similar': 1,
#  'Destructoid': 1,
#  'Chris': 1,
#  'Carter': 3,
#  'described': 1,
#  'open': 1,
#  'akin': 1,
#  'waltz': 1,
#  'could': 1,
#  'approached': 1,
#  'writing': 5,
#  'choices': 1,
#  'Dark': 2,
#  '26': 1,
#  'Brandin': 1,
#  'Tyrell': 4,
#  'IGN': 1,
#  'focus': 1,
#  'split-second': 1,
#  'swordsmanship': 2,
#  'despite': 1,
#  'fact': 1,
#  'veteran': 1,
#  'timing-based': 1,
#  'lock-on': 1,
#  'strikes': 2,
#  'slashes': 1,
#  'familiar': 2,
#  'sense': 3,
#  'safety': 1,
#  'caused': 1,
#  'refreshing': 1,
#  '33': 1,
#  'PC': 2,
#  'Gamer': 2,
#  'journalist': 2,
#  'Tom': 2,
#  'Senior': 3,
#  'called': 1,
#  'beautiful': 1,
#  'system': 2,
#  'chipping': 1,
#  'bars': 1,
#  'keels': 1,
#  'overwhelm': 1,
#  'bar': 1,
#  'perfect': 1,
#  'parries': 1,
#  'appears': 1,
#  'finish': 1,
#  'deathblow': 1,
#  '38': 1,
#  'stated': 1,
#  'catharsis': 1,
#  'beating': 1,
#  'great': 1,
#  'focuses': 1,
#  'emotion': 1,
#  'split': 1,
#  'second': 1,
#  'website': 1,
#  'GameSpot': 2,
#  'Tamoor': 1,
#  'Hussain': 3,
#  'wrote': 6,
#  'rewrites': 1,
#  'rules': 1,
#  'engagement': 1,
#  'stating': 1,
#  'previous': 2,
#  'demanded': 1,
#  'quick': 1,
#  'decision-making': 1,
#  'pushes': 1,
#  'demands': 1,
#  'ever': 2,
#  'Reviewers': 1,
#  'mechanic': 1,
#  'calling': 3,
#  'genius': 1,
#  'options': 1,
#  'gave': 1,
#  'freedom': 1,
#  'without': 2,
#  'descending': 1,
#  'frustration': 1,
#  'design': 3,
#  'Particular': 1,
#  'given': 1,
#  'increased': 1,
#  'verticality': 1,
#  'dedicated': 1,
#  'jump': 1,
#  'button': 2,
#  'sends': 1,
#  'ripples': 1,
#  'throughout': 1,
#  'Soulsborne': 2,
#  'characters': 1,
#  'felt': 1,
#  'rooted': 1,
#  'firmly': 1,
#  'ground': 1,
#  'trudged': 1,
#  'hallways': 1,
#  'slowly': 1,
#  'climbed': 1,
#  'ladders': 1,
#  'permission': 1,
#  'much': 1,
#  'vertical': 2,
#  'provided': 1,
#  'cases': 1,
#  'challenging': 1,
#  'standpoint': 1,
#  'large': 1,
#  'separate': 1,
#  'zones': 1,
#  'rather': 1,
#  'huge': 1,
#  'connected': 1,
#  'many': 1,
#  'secrets': 2,
#  'hidden': 2,
#  'critical': 1,
#  'path': 1,
#  'often': 1,
#  'reached': 2,
#  'excellent': 1,
#  'lets': 1,
#  'vault': 1,
#  'branches': 1,
#  'rooftops': 1,
#  'levels': 1,
#  'buildings': 1,
#  'placed': 1,
#  'together': 1,
#  'encourage': 1,
#  'reconnaissance': 1,
#  'roofs': 1,
#  'almost': 1,
#  'touching': 1,
#  'leap': 1,
#  'scope': 1,
#  'angles': 1,
#  'branching': 1,
#  'satisfying': 1,
#  'feeling': 1,
#  'venturing': 1,
#  'emerging': 1,
#  'Reaction': 1,
#  'lack': 2,
#  'online': 2,
#  'Several': 3,
#  'reviewers': 2,
#  'noted': 2,
#  'allowed': 1,
#  'pause': 1,
#  'missed': 1,
#  'small': 1,
#  'notes': 1,
#  'others': 1,
#  'alerting': 1,
#  'imminent': 1,
#  'threats': 1,
#  'vague': 1,
#  'danger': 1,
#  'lurks': 1,
#  'behind': 2,
#  'form': 1,
#  'invading': 1,
#  'defined': 1,
#  'playing': 1,
#  'noticed': 1,
#  'PvP': 1,
#  'seem': 1,
#  'ed': 1,
#  'waste': 1,
#  'skill-based': 1,
#  'argued': 4,
#  'parrying': 1,
#  'blocking': 1,
#  'mechanics': 1,
#  'suited': 2,
#  'play': 1,
#  'Similarly': 1,
#  'high': 1,
#  'polarised': 1,
#  'journalists': 2,
#  'brutal': 1,
#  'spectacular': 1,
#  'punishes': 1,
#  'missteps': 1,
#  'certain': 1,
#  'temperament': 1,
#  'specific': 1,
#  'slightly': 1,
#  'masochistic': 1,
#  'taste': 1,
#  'victory': 1,
#  'intense': 1,
#  'gratifying': 1,
#  'steep': 1,
#  'curve': 1,
#  'mastering': 1,
#  'somewhat': 1,
#  'easier': 3,
#  'predecessors': 1,
#  'still': 1,
#  'providing': 1,
#  'greatest': 1,
#  'swordsman': 1,
#  'lived': 1,
#  'tough': 2,
#  'victories': 1,
#  'Don': 1,
#  'Rowe': 1,
#  'Spinoff': 1,
#  'infuriating': 1,
#  'fun': 1,
#  'six': 1,
#  'hours': 1,
#  '39': 1,
#  'Forbes': 1,
#  'Dave': 1,
#  'Thier': 1,
#  'criticized': 1,
#  'decision': 1,
#  'claiming': 1,
#  'inaccessible': 1,
#  'lower': 1,
#  'respect': 1,
#  'add': 1,
#  '40': 1,
#  'modders': 1,
#  'managed': 1,
#  'develop': 1,
#  'mods': 1,
#  'make': 1,
#  'changing': 1,
#  'speed': 1,
#  'relative': 1,
#  '41': 1,
#  'James': 1,
#  'Davenport': 1,
#  'said': 1,
#  'difficult': 1,
#  'beat': 1,
#  'software': 1,
#  '42': 1,
#  'release': 2,
#  'drew': 1,
#  '108,000': 1,
#  'concurrent': 2,
#  'Steam': 3,
#  'highest': 2,
#  'launched': 1,
#  'January–March': 1,
#  'third': 1,
#  'platform': 2,
#  'Monster': 1,
#  'Hunter': 1,
#  'World': 1,
#  'III': 1,
#  '43': 1,
#  '44': 1,
#  'Later': 1,
#  '125,000': 1,
#  '45': 1,
#  'debut': 1,
#  'week': 1,
#  'topped': 1,
#  'UK': 1,
#  'EMEAA': 1,
#  'Europe': 1,
#  'Middle': 1,
#  'East': 1,
#  'Africa': 1,
#  'Asia': 1,
#  'charts': 1,
#  'surpassing': 1,
#  'Clancy': 1,
#  'Division': 1,
#  '46': 1,
#  '47': 1,
#  '48': 1,
#  'debuted': 1,
#  'first': 1,
#  '157,548': 1,
#  'retail': 1,
#  'weekend': 1,
#  '49': 1,
#  'Within': 1,
#  'ten': 1,
#  'two': 1,
#  'rose': 1,
#  '50': 1,
#  '51': 1,
#  'year': 1,
#  '52': 1,
#  'editors': 1,
#  '53': 1,
#  'fans': 1,
#  '54': 1}

# %%
# Normalizing the values of our word_frequencies dictionary

max_value = max(word_frequecies.values())

for k, v in word_frequecies.items():
    word_frequecies[k] = v / max_value

# %%
# Normalized dictionary

word_frequecies
# Out:
# {'Sekiro': 0.5178571428571429,
#  'Shadows': 0.08928571428571429,
#  'Die': 0.08928571428571429,
#  'Twice': 0.08928571428571429,
#  '2019': 0.10714285714285714,
#  'action-adventure': 0.03571428571428571,
#  'game': 0.6785714285714286,
#  'developed': 0.03571428571428571,
#  'FromSoftware': 0.17857142857142858,
#  'published': 0.05357142857142857,
#  'Activision': 0.05357142857142857,
#  'The': 0.4107142857142857,
#  'follows': 0.017857142857142856,
#  'shinobi': 0.10714285714285714,
#  'known': 0.10714285714285714,
#  'Wolf': 0.21428571428571427,
#  'attempts': 0.017857142857142856,
#  'take': 0.03571428571428571,
#  'revenge': 0.017857142857142856,
#  'samurai': 0.017857142857142856,
#  'clan': 0.05357142857142857,
#  'attacked': 0.017857142857142856,
#  'kidnapped': 0.017857142857142856,
#  'lord': 0.017857142857142856,
#  'It': 0.07142857142857142,
#  'released': 0.10714285714285714,
#  'Microsoft': 0.03571428571428571,
#  'Windows': 0.05357142857142857,
#  'PlayStation': 0.05357142857142857,
#  '4': 0.08928571428571429,
#  'Xbox': 0.05357142857142857,
#  'One': 0.05357142857142857,
#  'March': 0.05357142857142857,
#  'Stadia': 0.03571428571428571,
#  'October': 0.03571428571428571,
#  '2020': 0.08928571428571429,
#  'Gameplay': 0.017857142857142856,
#  'focused': 0.017857142857142856,
#  'stealth': 0.05357142857142857,
#  'exploration': 0.07142857142857142,
#  'combat': 0.19642857142857142,
#  'particular': 0.017857142857142856,
#  'emphasis': 0.05357142857142857,
#  'boss': 0.07142857142857142,
#  'battles': 0.03571428571428571,
#  'takes': 0.05357142857142857,
#  'place': 0.05357142857142857,
#  'fictionalized': 0.017857142857142856,
#  'Japan': 0.07142857142857142,
#  'Sengoku': 0.05357142857142857,
#  'period': 0.05357142857142857,
#  'makes': 0.017857142857142856,
#  'strong': 0.017857142857142856,
#  'references': 0.017857142857142856,
#  'Buddhist': 0.017857142857142856,
#  'mythology': 0.017857142857142856,
#  'philosophy': 0.017857142857142856,
#  'While': 0.03571428571428571,
#  'making': 0.05357142857142857,
#  'lead': 0.017857142857142856,
#  'director': 0.017857142857142856,
#  'Hidetaka': 0.03571428571428571,
#  'Miyazaki': 0.05357142857142857,
#  'wanted': 0.03571428571428571,
#  'create': 0.05357142857142857,
#  'new': 0.125,
#  'intellectual': 0.017857142857142856,
#  'property': 0.017857142857142856,
#  'IP': 0.017857142857142856,
#  'marked': 0.017857142857142856,
#  'departure': 0.017857142857142856,
#  'Souls': 0.125,
#  'series': 0.10714285714285714,
#  'games': 0.17857142857142858,
#  'also': 0.17857142857142858,
#  'made': 0.03571428571428571,
#  'developers': 0.017857142857142856,
#  'looked': 0.017857142857142856,
#  'Mysterious': 0.017857142857142856,
#  'Murasame': 0.017857142857142856,
#  'Castle': 0.03571428571428571,
#  'Tenchu': 0.05357142857142857,
#  'inspiration': 0.03571428571428571,
#  'praised': 0.19642857142857142,
#  'critics': 0.03571428571428571,
#  'complimented': 0.017857142857142856,
#  'gameplay': 0.03571428571428571,
#  'setting': 0.017857142857142856,
#  'compared': 0.017857142857142856,
#  'although': 0.017857142857142856,
#  'opinions': 0.017857142857142856,
#  'difficulty': 0.08928571428571429,
#  'mixed': 0.03571428571428571,
#  'nominated': 0.03571428571428571,
#  'various': 0.03571428571428571,
#  'awards': 0.03571428571428571,
#  'several': 0.07142857142857142,
#  'including': 0.03571428571428571,
#  'Game': 0.08928571428571429,
#  'Award': 0.017857142857142856,
#  'Year': 0.017857142857142856,
#  'sold': 0.05357142857142857,
#  'five': 0.03571428571428571,
#  'million': 0.05357142857142857,
#  'copies': 0.05357142857142857,
#  'July': 0.03571428571428571,
#  'played': 0.03571428571428571,
#  'third-person': 0.017857142857142856,
#  'view': 0.017857142857142856,
#  '1': 0.03571428571428571,
#  '2': 0.03571428571428571,
#  '3': 0.16071428571428573,
#  'Compared': 0.017857142857142856,
#  "'s": 0.5714285714285714,
#  'features': 0.03571428571428571,
#  'fewer': 0.017857142857142856,
#  'role-playing': 0.017857142857142856,
#  'elements': 0.05357142857142857,
#  'lacking': 0.017857142857142856,
#  'character': 0.08928571428571429,
#  'creation': 0.017857142857142856,
#  'ability': 0.03571428571428571,
#  'level': 0.10714285714285714,
#  'variety': 0.03571428571428571,
#  'stats': 0.017857142857142856,
#  'well': 0.017857142857142856,
#  'multiplayer': 0.05357142857142857,
#  '5': 0.017857142857142856,
#  '6': 0.03571428571428571,
#  'however': 0.017857142857142856,
#  'include': 0.017857142857142856,
#  'gear': 0.017857142857142856,
#  'upgrading': 0.017857142857142856,
#  'skill': 0.03571428571428571,
#  'tree': 0.03571428571428571,
#  'limited': 0.017857142857142856,
#  'customization': 0.017857142857142856,
#  'Rather': 0.017857142857142856,
#  'attacking': 0.017857142857142856,
#  'whittle': 0.017857142857142856,
#  'enemy': 0.03571428571428571,
#  'health': 0.05357142857142857,
#  'points': 0.017857142857142856,
#  'revolves': 0.017857142857142856,
#  'around': 0.017857142857142856,
#  'using': 0.03571428571428571,
#  'katana': 0.017857142857142856,
#  'attack': 0.05357142857142857,
#  'posture': 0.05357142857142857,
#  'balance': 0.017857142857142856,
#  'instead': 0.08928571428571429,
#  'eventually': 0.03571428571428571,
#  'leads': 0.03571428571428571,
#  'opening': 0.07142857142857142,
#  'allows': 0.017857142857142856,
#  'single': 0.017857142857142856,
#  'killing': 0.017857142857142856,
#  'blow': 0.017857142857142856,
#  '7': 0.017857142857142856,
#  'allowing': 0.017857142857142856,
#  'players': 0.125,
#  'instantly': 0.017857142857142856,
#  'eliminate': 0.017857142857142856,
#  'enemies': 0.03571428571428571,
#  'get': 0.017857142857142856,
#  'range': 0.017857142857142856,
#  'undetected': 0.017857142857142856,
#  'In': 0.08928571428571429,
#  'addition': 0.03571428571428571,
#  'player': 0.10714285714285714,
#  'use': 0.017857142857142856,
#  'tools': 0.017857142857142856,
#  'assist': 0.017857142857142856,
#  'grappling': 0.07142857142857142,
#  'hook': 0.08928571428571429,
#  'If': 0.05357142857142857,
#  'dies': 0.03571428571428571,
#  'option': 0.017857142857142856,
#  'revived': 0.017857142857142856,
#  'spot': 0.017857142857142856,
#  'resurrection': 0.03571428571428571,
#  'power': 0.017857142857142856,
#  'restored': 0.017857142857142856,
#  'defeating': 0.05357142857142857,
#  'respawning': 0.017857142857142856,
#  'earlier': 0.017857142857142856,
#  'checkpoints': 0.017857142857142856,
#  'Following': 0.017857142857142856,
#  'Isshin': 0.17857142857142858,
#  'Ashina': 0.10714285714285714,
#  'seized': 0.017857142857142856,
#  'control': 0.017857142857142856,
#  'land': 0.017857142857142856,
#  'During': 0.017857142857142856,
#  'time': 0.05357142857142857,
#  'nameless': 0.017857142857142856,
#  'orphan': 0.017857142857142856,
#  'adopted': 0.017857142857142856,
#  'wandering': 0.017857142857142856,
#  '``': 1.0,
#  'Owl': 0.10714285714285714,
#  "''": 0.9642857142857143,
#  'named': 0.017857142857142856,
#  'boy': 0.03571428571428571,
#  'trained': 0.017857142857142856,
#  'ways': 0.03571428571428571,
#  'Two': 0.017857142857142856,
#  'decades': 0.017857142857142856,
#  'later': 0.017857142857142856,
#  'brink': 0.017857142857142856,
#  'collapse': 0.017857142857142856,
#  'due': 0.03571428571428571,
#  'elderly': 0.017857142857142856,
#  'falling': 0.017857142857142856,
#  'ill': 0.017857142857142856,
#  'Interior': 0.03571428571428571,
#  'Ministry': 0.03571428571428571,
#  'group': 0.017857142857142856,
#  'set': 0.03571428571428571,
#  'unifying': 0.017857142857142856,
#  'steadily': 0.017857142857142856,
#  'closing': 0.017857142857142856,
#  'Desperate': 0.017857142857142856,
#  'save': 0.017857142857142856,
#  'adoptive': 0.017857142857142856,
#  'grandson': 0.03571428571428571,
#  'Genichiro': 0.14285714285714285,
#  'seeks': 0.03571428571428571,
#  'immortal': 0.07142857142857142,
#  'Divine': 0.07142857142857142,
#  'Heir': 0.017857142857142856,
#  'Kuro': 0.26785714285714285,
#  'hopes': 0.017857142857142856,
#  'Dragon': 0.14285714285714285,
#  'Heritage': 0.125,
#  'blood': 0.017857142857142856,
#  'army': 0.017857142857142856,
#  'full-fledged': 0.017857142857142856,
#  'personal': 0.017857142857142856,
#  'bodyguard': 0.017857142857142856,
#  'fights': 0.05357142857142857,
#  'loses': 0.017857142857142856,
#  'duel': 0.017857142857142856,
#  'along': 0.017857142857142856,
#  'left': 0.03571428571428571,
#  'arm': 0.017857142857142856,
#  'However': 0.08928571428571429,
#  'survives': 0.03571428571428571,
#  'found': 0.03571428571428571,
#  'retired': 0.017857142857142856,
#  'Sculpter': 0.017857142857142856,
#  'nurses': 0.017857142857142856,
#  'back': 0.05357142857142857,
#  'gifts': 0.017857142857142856,
#  'Shinobi': 0.017857142857142856,
#  'Prosthetic': 0.017857142857142856,
#  '8': 0.017857142857142856,
#  '9': 0.017857142857142856,
#  'To': 0.017857142857142856,
#  'rescue': 0.017857142857142856,
#  'assaults': 0.017857142857142856,
#  'whilst': 0.017857142857142856,
#  'forced': 0.03571428571428571,
#  'confront': 0.017857142857142856,
#  'past': 0.017857142857142856,
#  'three': 0.03571428571428571,
#  'years': 0.017857142857142856,
#  'ago': 0.017857142857142856,
#  'birthplace': 0.017857142857142856,
#  'Hirata': 0.03571428571428571,
#  'estate': 0.017857142857142856,
#  'raided': 0.017857142857142856,
#  'bandits': 0.017857142857142856,
#  'led': 0.017857142857142856,
#  'former': 0.017857142857142856,
#  'teacher': 0.017857142857142856,
#  'Lady': 0.017857142857142856,
#  'Butterfly': 0.017857142857142856,
#  'attempting': 0.017857142857142856,
#  'kidnap': 0.017857142857142856,
#  'able': 0.017857142857142856,
#  'defeat': 0.017857142857142856,
#  'stabbed': 0.017857142857142856,
#  'unknown': 0.03571428571428571,
#  'assailant': 0.017857142857142856,
#  'survived': 0.017857142857142856,
#  'thanks': 0.017857142857142856,
#  'Back': 0.017857142857142856,
#  'present': 0.017857142857142856,
#  'confronts': 0.017857142857142856,
#  'defeats': 0.017857142857142856,
#  'drinking': 0.017857142857142856,
#  'artificial': 0.017857142857142856,
#  'replication': 0.017857142857142856,
#  'Rejuvenating': 0.03571428571428571,
#  'Waters': 0.03571428571428571,
#  'flees': 0.017857142857142856,
#  'asks': 0.017857142857142856,
#  'perform': 0.017857142857142856,
#  'Immortal': 0.03571428571428571,
#  'Severance': 0.03571428571428571,
#  'ritual': 0.10714285714285714,
#  'would': 0.05357142857142857,
#  'result': 0.017857142857142856,
#  'death': 0.017857142857142856,
#  'prevent': 0.017857142857142856,
#  'anyone': 0.017857142857142856,
#  'fighting': 0.017857142857142856,
#  'immortality': 0.03571428571428571,
#  'reluctantly': 0.017857142857142856,
#  'agrees': 0.017857142857142856,
#  'help': 0.03571428571428571,
#  'sets': 0.017857142857142856,
#  'collect': 0.03571428571428571,
#  'necessary': 0.017857142857142856,
#  'materials': 0.017857142857142856,
#  'quest': 0.017857142857142856,
#  'cross': 0.017857142857142856,
#  'paths': 0.03571428571428571,
#  'gives': 0.017857142857142856,
#  'name': 0.03571428571428571,
#  'one-armed': 0.03571428571428571,
#  'wolf': 0.03571428571428571,
#  'After': 0.03571428571428571,
#  'collecting': 0.017857142857142856,
#  'components': 0.017857142857142856,
#  'confronted': 0.017857142857142856,
#  'thought': 0.017857142857142856,
#  'killed': 0.017857142857142856,
#  'raid': 0.017857142857142856,
#  'revealed': 0.05357142857142857,
#  'one': 0.07142857142857142,
#  'back-stabbed': 0.017857142857142856,
#  'reveals': 0.017857142857142856,
#  'orders': 0.017857142857142856,
#  'renounce': 0.017857142857142856,
#  'loyalty': 0.017857142857142856,
#  'sides': 0.017857142857142856,
#  'fight': 0.017857142857142856,
#  'doctor': 0.017857142857142856,
#  'Emma': 0.03571428571428571,
#  'Upon': 0.03571428571428571,
#  'proceeds': 0.017857142857142856,
#  'betray': 0.017857142857142856,
#  'realizes': 0.017857142857142856,
#  'corrupted': 0.017857142857142856,
#  'bloodlust': 0.017857142857142856,
#  'resulting': 0.017857142857142856,
#  'Shura': 0.017857142857142856,
#  'ending': 0.07142857142857142,
#  'chosen': 0.017857142857142856,
#  'kills': 0.017857142857142856,
#  'enters': 0.017857142857142856,
#  'Realm': 0.017857142857142856,
#  'final': 0.07142857142857142,
#  'material': 0.017857142857142856,
#  'returning': 0.017857142857142856,
#  'discovers': 0.017857142857142856,
#  'succumbed': 0.017857142857142856,
#  'illness': 0.017857142857142856,
#  'castle': 0.017857142857142856,
#  'finds': 0.017857142857142856,
#  'challenges': 0.017857142857142856,
#  'defeated': 0.017857142857142856,
#  'Realizing': 0.017857142857142856,
#  'lost': 0.017857142857142856,
#  'uses': 0.017857142857142856,
#  'revive': 0.017857142857142856,
#  'prime': 0.017857142857142856,
#  'might': 0.017857142857142856,
#  'restore': 0.017857142857142856,
#  'cost': 0.03571428571428571,
#  'life': 0.03571428571428571,
#  'Although': 0.017857142857142856,
#  'disagrees': 0.017857142857142856,
#  'methods': 0.017857142857142856,
#  'honors': 0.017857142857142856,
#  'wish': 0.017857142857142856,
#  'possible': 0.017857142857142856,
#  'endings': 0.017857142857142856,
#  'Performing': 0.017857142857142856,
#  'results': 0.03571428571428571,
#  'eponymous': 0.017857142857142856,
#  'standard': 0.017857142857142856,
#  'removed': 0.017857142857142856,
#  'Afterward': 0.017857142857142856,
#  'like': 0.03571428571428571,
#  'Sculptor': 0.017857142857142856,
#  'retires': 0.017857142857142856,
#  'spends': 0.017857142857142856,
#  'remainder': 0.017857142857142856,
#  'days': 0.05357142857142857,
#  'carving': 0.017857142857142856,
#  'Buddha': 0.017857142857142856,
#  'Statues': 0.017857142857142856,
#  'Working': 0.017857142857142856,
#  'find': 0.017857142857142856,
#  'alternative': 0.017857142857142856,
#  'way': 0.017857142857142856,
#  'severing': 0.017857142857142856,
#  'Purification': 0.017857142857142856,
#  'sacrifices': 0.017857142857142856,
#  'Homecoming': 0.017857142857142856,
#  'obtained': 0.03571428571428571,
#  'helping': 0.017857142857142856,
#  'Child': 0.03571428571428571,
#  'body': 0.017857142857142856,
#  'spirit': 0.017857142857142856,
#  'lives': 0.017857142857142856,
#  'inside': 0.017857142857142856,
#  'goes': 0.017857142857142856,
#  'journey': 0.017857142857142856,
#  'return': 0.017857142857142856,
#  'origin': 0.017857142857142856,
#  'Development': 0.017857142857142856,
#  'began': 0.017857142857142856,
#  'late': 0.03571428571428571,
#  '2015': 0.017857142857142856,
#  'following': 0.017857142857142856,
#  'completion': 0.017857142857142856,
#  'Bloodborne': 0.05357142857142857,
#  'downloadable': 0.017857142857142856,
#  'content': 0.03571428571428571,
#  'Old': 0.017857142857142856,
#  'Hunters': 0.017857142857142856,
#  '10': 0.03571428571428571,
#  'via': 0.017857142857142856,
#  'teaser': 0.03571428571428571,
#  'trailer': 0.03571428571428571,
#  'Awards': 0.05357142857142857,
#  '2017': 0.017857142857142856,
#  'December': 0.017857142857142856,
#  'showing': 0.017857142857142856,
#  'tagline': 0.017857142857142856,
#  '11': 0.017857142857142856,
#  'full': 0.03571428571428571,
#  'title': 0.017857142857142856,
#  'press': 0.017857142857142856,
#  'conference': 0.017857142857142856,
#  'E3': 0.017857142857142856,
#  '2018': 0.017857142857142856,
#  'directed': 0.017857142857142856,
#  'Japanese': 0.05357142857142857,
#  'development': 0.017857142857142856,
#  'studio': 0.03571428571428571,
#  'best': 0.017857142857142856,
#  'creating': 0.03571428571428571,
#  '12': 0.017857142857142856,
#  'worldwide': 0.03571428571428571,
#  'self-publishing': 0.017857142857142856,
#  'Cube': 0.017857142857142856,
#  'publishing': 0.017857142857142856,
#  'Asia-Pacific': 0.017857142857142856,
#  'region': 0.017857142857142856,
#  '13': 0.017857142857142856,
#  '14': 0.017857142857142856,
#  'soundtrack': 0.03571428571428571,
#  'composed': 0.017857142857142856,
#  'Yuka': 0.017857142857142856,
#  'Kitamura': 0.017857142857142856,
#  '15': 0.017857142857142856,
#  'contributions': 0.017857142857142856,
#  'Noriyuki': 0.017857142857142856,
#  'Asakura': 0.017857142857142856,
#  '22': 0.03571428571428571,
#  '16': 0.03571428571428571,
#  'A': 0.03571428571428571,
#  'collectors': 0.017857142857142856,
#  'edition': 0.017857142857142856,
#  'day': 0.03571428571428571,
#  'included': 0.017857142857142856,
#  'steelbook': 0.017857142857142856,
#  'case': 0.017857142857142856,
#  'figurine': 0.017857142857142856,
#  'protagonist': 0.017857142857142856,
#  'art': 0.017857142857142856,
#  'book': 0.017857142857142856,
#  'physical': 0.017857142857142856,
#  'map': 0.017857142857142856,
#  'world': 0.05357142857142857,
#  'download': 0.017857142857142856,
#  'code': 0.017857142857142856,
#  'in-game': 0.017857142857142856,
#  'coin': 0.017857142857142856,
#  'replicas': 0.017857142857142856,
#  'port': 0.017857142857142856,
#  '17': 0.017857142857142856,
#  'draws': 0.017857142857142856,
#  'stealth-action': 0.017857142857142856,
#  'partially': 0.017857142857142856,
#  '18': 0.017857142857142856,
#  'team': 0.03571428571428571,
#  'initially': 0.03571428571428571,
#  'considered': 0.017857142857142856,
#  'developing': 0.017857142857142856,
#  'sequel': 0.017857142857142856,
#  'already': 0.017857142857142856,
#  'shaped': 0.017857142857142856,
#  'different': 0.03571428571428571,
#  'studios': 0.017857142857142856,
#  'rights': 0.017857142857142856,
#  'opted': 0.017857142857142856,
#  'project': 0.017857142857142856,
#  'direction': 0.017857142857142856,
#  'intended': 0.017857142857142856,
#  'changes': 0.017857142857142856,
#  'capture': 0.017857142857142856,
#  'feel': 0.03571428571428571,
#  'swords': 0.017857142857142856,
#  'clashing': 0.017857142857142856,
#  'fighters': 0.017857142857142856,
#  'trying': 0.017857142857142856,
#  'deliver': 0.017857142857142856,
#  'fatal': 0.017857142857142856,
#  'strike': 0.017857142857142856,
#  'He': 0.07142857142857142,
#  'created': 0.017857142857142856,
#  'entirely': 0.017857142857142856,
#  'single-player': 0.017857142857142856,
#  'experience': 0.03571428571428571,
#  'believed': 0.017857142857142856,
#  'limitations': 0.017857142857142856,
#  'avoid': 0.017857142857142856,
#  'word': 0.017857142857142856,
#  'sekirō': 0.017857142857142856,
#  '隻狼': 0.017857142857142856,
#  'contraction': 0.017857142857142856,
#  'sekiwan': 0.017857142857142856,
#  'ōkami': 0.017857142857142856,
#  '隻腕の狼': 0.017857142857142856,
#  'translates': 0.017857142857142856,
#  '19': 0.017857142857142856,
#  'subtitle': 0.017857142857142856,
#  'meant': 0.017857142857142856,
#  'used': 0.03571428571428571,
#  'slogan': 0.017857142857142856,
#  'requested': 0.017857142857142856,
#  'kept': 0.017857142857142856,
#  '20': 0.017857142857142856,
#  'Despite': 0.017857142857142856,
#  'taking': 0.017857142857142856,
#  'real-world': 0.017857142857142856,
#  'history': 0.03571428571428571,
#  'historical': 0.017857142857142856,
#  'people': 0.03571428571428571,
#  'locations': 0.017857142857142856,
#  'featured': 0.017857142857142856,
#  '21': 0.017857142857142856,
#  'On': 0.03571428571428571,
#  '31': 0.03571428571428571,
#  'free': 0.017857142857142856,
#  'update': 0.017857142857142856,
#  'added': 0.017857142857142856,
#  'cosmetics': 0.017857142857142856,
#  'rush': 0.017857142857142856,
#  'mode': 0.03571428571428571,
#  'According': 0.017857142857142856,
#  'review': 0.05357142857142857,
#  'aggregator': 0.017857142857142856,
#  'Metacritic': 0.017857142857142856,
#  'received': 0.017857142857142856,
#  'universal': 0.017857142857142856,
#  'acclaim': 0.017857142857142856,
#  'versions': 0.017857142857142856,
#  'generally': 0.017857142857142856,
#  'favorable': 0.017857142857142856,
#  'reviews': 0.017857142857142856,
#  'version': 0.017857142857142856,
#  '23': 0.017857142857142856,
#  '24': 0.017857142857142856,
#  '25': 0.017857142857142856,
#  'Many': 0.017857142857142856,
#  'departing': 0.017857142857142856,
#  'typical': 0.017857142857142856,
#  'style': 0.017857142857142856,
#  'similar': 0.017857142857142856,
#  'Destructoid': 0.017857142857142856,
#  'Chris': 0.017857142857142856,
#  'Carter': 0.05357142857142857,
#  'described': 0.017857142857142856,
#  'open': 0.017857142857142856,
#  'akin': 0.017857142857142856,
#  'waltz': 0.017857142857142856,
#  'could': 0.017857142857142856,
#  'approached': 0.017857142857142856,
#  'writing': 0.08928571428571429,
#  'choices': 0.017857142857142856,
#  'Dark': 0.03571428571428571,
#  '26': 0.017857142857142856,
#  'Brandin': 0.017857142857142856,
#  'Tyrell': 0.07142857142857142,
#  'IGN': 0.017857142857142856,
#  'focus': 0.017857142857142856,
#  'split-second': 0.017857142857142856,
#  'swordsmanship': 0.03571428571428571,
#  'despite': 0.017857142857142856,
#  'fact': 0.017857142857142856,
#  'veteran': 0.017857142857142856,
#  'timing-based': 0.017857142857142856,
#  'lock-on': 0.017857142857142856,
#  'strikes': 0.03571428571428571,
#  'slashes': 0.017857142857142856,
#  'familiar': 0.03571428571428571,
#  'sense': 0.05357142857142857,
#  'safety': 0.017857142857142856,
#  'caused': 0.017857142857142856,
#  'refreshing': 0.017857142857142856,
#  '33': 0.017857142857142856,
#  'PC': 0.03571428571428571,
#  'Gamer': 0.03571428571428571,
#  'journalist': 0.03571428571428571,
#  'Tom': 0.03571428571428571,
#  'Senior': 0.05357142857142857,
#  'called': 0.017857142857142856,
#  'beautiful': 0.017857142857142856,
#  'system': 0.03571428571428571,
#  'chipping': 0.017857142857142856,
#  'bars': 0.017857142857142856,
#  'keels': 0.017857142857142856,
#  'overwhelm': 0.017857142857142856,
#  'bar': 0.017857142857142856,
#  'perfect': 0.017857142857142856,
#  'parries': 0.017857142857142856,
#  'appears': 0.017857142857142856,
#  'finish': 0.017857142857142856,
#  'deathblow': 0.017857142857142856,
#  '38': 0.017857142857142856,
#  'stated': 0.017857142857142856,
#  'catharsis': 0.017857142857142856,
#  'beating': 0.017857142857142856,
#  'great': 0.017857142857142856,
#  'focuses': 0.017857142857142856,
#  'emotion': 0.017857142857142856,
#  'split': 0.017857142857142856,
#  'second': 0.017857142857142856,
#  'website': 0.017857142857142856,
#  'GameSpot': 0.03571428571428571,
#  'Tamoor': 0.017857142857142856,
#  'Hussain': 0.05357142857142857,
#  'wrote': 0.10714285714285714,
#  'rewrites': 0.017857142857142856,
#  'rules': 0.017857142857142856,
#  'engagement': 0.017857142857142856,
#  'stating': 0.017857142857142856,
#  'previous': 0.03571428571428571,
#  'demanded': 0.017857142857142856,
#  'quick': 0.017857142857142856,
#  'decision-making': 0.017857142857142856,
#  'pushes': 0.017857142857142856,
#  'demands': 0.017857142857142856,
#  'ever': 0.03571428571428571,
#  'Reviewers': 0.017857142857142856,
#  'mechanic': 0.017857142857142856,
#  'calling': 0.05357142857142857,
#  'genius': 0.017857142857142856,
#  'options': 0.017857142857142856,
#  'gave': 0.017857142857142856,
#  'freedom': 0.017857142857142856,
#  'without': 0.03571428571428571,
#  'descending': 0.017857142857142856,
#  'frustration': 0.017857142857142856,
#  'design': 0.05357142857142857,
#  'Particular': 0.017857142857142856,
#  'given': 0.017857142857142856,
#  'increased': 0.017857142857142856,
#  'verticality': 0.017857142857142856,
#  'dedicated': 0.017857142857142856,
#  'jump': 0.017857142857142856,
#  'button': 0.03571428571428571,
#  'sends': 0.017857142857142856,
#  'ripples': 0.017857142857142856,
#  'throughout': 0.017857142857142856,
#  'Soulsborne': 0.03571428571428571,
#  'characters': 0.017857142857142856,
#  'felt': 0.017857142857142856,
#  'rooted': 0.017857142857142856,
#  'firmly': 0.017857142857142856,
#  'ground': 0.017857142857142856,
#  'trudged': 0.017857142857142856,
#  'hallways': 0.017857142857142856,
#  'slowly': 0.017857142857142856,
#  'climbed': 0.017857142857142856,
#  'ladders': 0.017857142857142856,
#  'permission': 0.017857142857142856,
#  'much': 0.017857142857142856,
#  'vertical': 0.03571428571428571,
#  'provided': 0.017857142857142856,
#  'cases': 0.017857142857142856,
#  'challenging': 0.017857142857142856,
#  'standpoint': 0.017857142857142856,
#  'large': 0.017857142857142856,
#  'separate': 0.017857142857142856,
#  'zones': 0.017857142857142856,
#  'rather': 0.017857142857142856,
#  'huge': 0.017857142857142856,
#  'connected': 0.017857142857142856,
#  'many': 0.017857142857142856,
#  'secrets': 0.03571428571428571,
#  'hidden': 0.03571428571428571,
#  'critical': 0.017857142857142856,
#  'path': 0.017857142857142856,
#  'often': 0.017857142857142856,
#  'reached': 0.03571428571428571,
#  'excellent': 0.017857142857142856,
#  'lets': 0.017857142857142856,
#  'vault': 0.017857142857142856,
#  'branches': 0.017857142857142856,
#  'rooftops': 0.017857142857142856,
#  'levels': 0.017857142857142856,
#  'buildings': 0.017857142857142856,
#  'placed': 0.017857142857142856,
#  'together': 0.017857142857142856,
#  'encourage': 0.017857142857142856,
#  'reconnaissance': 0.017857142857142856,
#  'roofs': 0.017857142857142856,
#  'almost': 0.017857142857142856,
#  'touching': 0.017857142857142856,
#  'leap': 0.017857142857142856,
#  'scope': 0.017857142857142856,
#  'angles': 0.017857142857142856,
#  'branching': 0.017857142857142856,
#  'satisfying': 0.017857142857142856,
#  'feeling': 0.017857142857142856,
#  'venturing': 0.017857142857142856,
#  'emerging': 0.017857142857142856,
#  'Reaction': 0.017857142857142856,
#  'lack': 0.03571428571428571,
#  'online': 0.03571428571428571,
#  'Several': 0.05357142857142857,
#  'reviewers': 0.03571428571428571,
#  'noted': 0.03571428571428571,
#  'allowed': 0.017857142857142856,
#  'pause': 0.017857142857142856,
#  'missed': 0.017857142857142856,
#  'small': 0.017857142857142856,
#  'notes': 0.017857142857142856,
#  'others': 0.017857142857142856,
#  'alerting': 0.017857142857142856,
#  'imminent': 0.017857142857142856,
#  'threats': 0.017857142857142856,
#  'vague': 0.017857142857142856,
#  'danger': 0.017857142857142856,
#  'lurks': 0.017857142857142856,
#  'behind': 0.03571428571428571,
#  'form': 0.017857142857142856,
#  'invading': 0.017857142857142856,
#  'defined': 0.017857142857142856,
#  'playing': 0.017857142857142856,
#  'noticed': 0.017857142857142856,
#  'PvP': 0.017857142857142856,
#  'seem': 0.017857142857142856,
#  'ed': 0.017857142857142856,
#  'waste': 0.017857142857142856,
#  'skill-based': 0.017857142857142856,
#  'argued': 0.07142857142857142,
#  'parrying': 0.017857142857142856,
#  'blocking': 0.017857142857142856,
#  'mechanics': 0.017857142857142856,
#  'suited': 0.03571428571428571,
#  'play': 0.017857142857142856,
#  'Similarly': 0.017857142857142856,
#  'high': 0.017857142857142856,
#  'polarised': 0.017857142857142856,
#  'journalists': 0.03571428571428571,
#  'brutal': 0.017857142857142856,
#  'spectacular': 0.017857142857142856,
#  'punishes': 0.017857142857142856,
#  'missteps': 0.017857142857142856,
#  'certain': 0.017857142857142856,
#  'temperament': 0.017857142857142856,
#  'specific': 0.017857142857142856,
#  'slightly': 0.017857142857142856,
#  'masochistic': 0.017857142857142856,
#  'taste': 0.017857142857142856,
#  'victory': 0.017857142857142856,
#  'intense': 0.017857142857142856,
#  'gratifying': 0.017857142857142856,
#  'steep': 0.017857142857142856,
#  'curve': 0.017857142857142856,
#  'mastering': 0.017857142857142856,
#  'somewhat': 0.017857142857142856,
#  'easier': 0.05357142857142857,
#  'predecessors': 0.017857142857142856,
#  'still': 0.017857142857142856,
#  'providing': 0.017857142857142856,
#  'greatest': 0.017857142857142856,
#  'swordsman': 0.017857142857142856,
#  'lived': 0.017857142857142856,
#  'tough': 0.03571428571428571,
#  'victories': 0.017857142857142856,
#  'Don': 0.017857142857142856,
#  'Rowe': 0.017857142857142856,
#  'Spinoff': 0.017857142857142856,
#  'infuriating': 0.017857142857142856,
#  'fun': 0.017857142857142856,
#  'six': 0.017857142857142856,
#  'hours': 0.017857142857142856,
#  '39': 0.017857142857142856,
#  'Forbes': 0.017857142857142856,
#  'Dave': 0.017857142857142856,
#  'Thier': 0.017857142857142856,
#  'criticized': 0.017857142857142856,
#  'decision': 0.017857142857142856,
#  'claiming': 0.017857142857142856,
#  'inaccessible': 0.017857142857142856,
#  'lower': 0.017857142857142856,
#  'respect': 0.017857142857142856,
#  'add': 0.017857142857142856,
#  '40': 0.017857142857142856,
#  'modders': 0.017857142857142856,
#  'managed': 0.017857142857142856,
#  'develop': 0.017857142857142856,
#  'mods': 0.017857142857142856,
#  'make': 0.017857142857142856,
#  'changing': 0.017857142857142856,
#  'speed': 0.017857142857142856,
#  'relative': 0.017857142857142856,
#  '41': 0.017857142857142856,
#  'James': 0.017857142857142856,
#  'Davenport': 0.017857142857142856,
#  'said': 0.017857142857142856,
#  'difficult': 0.017857142857142856,
#  'beat': 0.017857142857142856,
#  'software': 0.017857142857142856,
#  '42': 0.017857142857142856,
#  'release': 0.03571428571428571,
#  'drew': 0.017857142857142856,
#  '108,000': 0.017857142857142856,
#  'concurrent': 0.03571428571428571,
#  'Steam': 0.05357142857142857,
#  'highest': 0.03571428571428571,
#  'launched': 0.017857142857142856,
#  'January–March': 0.017857142857142856,
#  'third': 0.017857142857142856,
#  'platform': 0.03571428571428571,
#  'Monster': 0.017857142857142856,
#  'Hunter': 0.017857142857142856,
#  'World': 0.017857142857142856,
#  'III': 0.017857142857142856,
#  '43': 0.017857142857142856,
#  '44': 0.017857142857142856,
#  'Later': 0.017857142857142856,
#  '125,000': 0.017857142857142856,
#  '45': 0.017857142857142856,
#  'debut': 0.017857142857142856,
#  'week': 0.017857142857142856,
#  'topped': 0.017857142857142856,
#  'UK': 0.017857142857142856,
#  'EMEAA': 0.017857142857142856,
#  'Europe': 0.017857142857142856,
#  'Middle': 0.017857142857142856,
#  'East': 0.017857142857142856,
#  'Africa': 0.017857142857142856,
#  'Asia': 0.017857142857142856,
#  'charts': 0.017857142857142856,
#  'surpassing': 0.017857142857142856,
#  'Clancy': 0.017857142857142856,
#  'Division': 0.017857142857142856,
#  '46': 0.017857142857142856,
#  '47': 0.017857142857142856,
#  '48': 0.017857142857142856,
#  'debuted': 0.017857142857142856,
#  'first': 0.017857142857142856,
#  '157,548': 0.017857142857142856,
#  'retail': 0.017857142857142856,
#  'weekend': 0.017857142857142856,
#  '49': 0.017857142857142856,
#  'Within': 0.017857142857142856,
#  'ten': 0.017857142857142856,
#  'two': 0.017857142857142856,
#  'rose': 0.017857142857142856,
#  '50': 0.017857142857142856,
#  '51': 0.017857142857142856,
#  'year': 0.017857142857142856,
#  '52': 0.017857142857142856,
#  'editors': 0.017857142857142856,
#  '53': 0.017857142857142856,
#  'fans': 0.017857142857142856,
#  '54': 0.017857142857142856}

# %%
# Tokenizing the article into a sentences

sentences = nltk.sent_tokenize(article_content)
sentences
# Out:
# ['\n\nSekiro: Shadows Die Twice[a] is a 2019 action-adventure game developed by FromSoftware and published by Activision.',
#  'The game follows a shinobi known as Wolf as he attempts to take revenge on a samurai clan who attacked him and kidnapped his lord.',
#  'It was released for Microsoft Windows, PlayStation 4, and Xbox One in March 2019 and for Stadia in October 2020.',
#  'Gameplay is focused on stealth, exploration, and combat, with a particular emphasis on boss battles.',
#  'The game takes place in a fictionalized Japan during the Sengoku period and makes strong references to Buddhist mythology and philosophy.',
#  'While making the game, lead director Hidetaka Miyazaki wanted to create a new intellectual property (IP) that marked a departure from the Souls series of games also made by FromSoftware.',
#  'The developers looked to games such as The Mysterious Murasame Castle and the Tenchu series for inspiration.',
#  'Sekiro was praised by critics, who complimented its gameplay and setting, and compared it to the Souls games, although opinions on its difficulty were mixed.',
#  'It was nominated for various awards and won several, including The Game Award for Game of the Year.',
#  'The game sold over five million copies by July 2020.',
#  'Sekiro: Shadows Die Twice is an action-adventure game played from a third-person view.',
#  "[1][2][3][4] Compared to FromSoftware's Souls series, the game features fewer role-playing elements, lacking character creation and the ability to level up a variety of stats, as well as having no multiplayer elements.",
#  '[3][4][5][6] It does, however, include gear upgrading, a skill tree, and limited ability customization.',
#  "Rather than attacking to whittle an enemy's health points, combat in Sekiro revolves around using a katana to attack their posture and balance instead, which eventually leads to an opening that allows for a single killing blow.",
#  '[3][7]\nThe game also features stealth elements, allowing players to instantly eliminate some enemies if they can get in range undetected.',
#  '[3] In addition, the player character can use various tools to assist with combat and exploration, such as a grappling hook.',
#  '[3] If the player character dies, they have the option of being revived on the spot if they have resurrection power, which is restored by defeating enemies, instead of respawning at earlier checkpoints.',
#  '[3]\nFollowing the Sengoku period, Isshin Ashina seized control of the land of Ashina.',
#  '[1] During this time, a nameless orphan is adopted by the wandering shinobi known as "Owl", who named the boy "Wolf", and trained him in the ways of the shinobi.',
#  'Two decades later, Ashina is on the brink of collapse due to the now elderly Isshin falling ill and the Interior Ministry, a group set on unifying Japan, steadily closing in.',
#  'Desperate to save his clan, Isshin\'s adoptive grandson Genichiro seeks the immortal "Divine Heir" Kuro in hopes of using the "Dragon Heritage" in his blood to create an immortal army.',
#  "Wolf, now a full-fledged shinobi and Kuro's personal bodyguard, fights Genichiro but loses the duel along with his left arm while Genichiro takes the boy.",
#  'However, being immortal himself, Wolf survives and is found by a retired shinobi known as the "Sculpter", who nurses him \nback to health and gifts him a Shinobi Prosthetic.',
#  "[3][8][9]\nTo rescue Kuro, Wolf assaults Ashina Castle whilst being forced to confront his own past: three years ago, Kuro's birthplace, the Hirata estate, was raided by bandits led by Wolf's former teacher, Lady Butterfly, who was attempting to kidnap Kuro.",
#  "While Wolf was able to defeat her, he was then stabbed in the back by an unknown assailant but survived thanks to Kuro making him immortal through the Dragon's Heritage.",
#  'Back in the present, Wolf once again confronts Genichiro and this time, defeats him.',
#  'However, Genichiro survives by drinking an artificial replication of the Dragon Heritage known as the "Rejuvenating Waters", and flees.',
#  'Kuro then asks Wolf to perform the "Immortal Severance" ritual, which would result in Kuro\'s death and prevent anyone from fighting over his immortality.',
#  'Wolf reluctantly agrees to help and sets out to collect the necessary materials for the ritual.',
#  'Wolf\'s quest also leads him to cross paths with Isshin, who gives him a new name: "Sekiro", the "one-armed wolf".',
#  'After collecting all the components for the ritual, Sekiro is confronted by Owl, who was thought to have been killed during the raid on Hirata and revealed to be the one who back-stabbed Sekiro back then.',
#  'Owl reveals he also seeks the Dragon Heritage and orders Sekiro to renounce his loyalty to Kuro.',
#  "If Sekiro sides with Owl, he is forced to fight Isshin's doctor, Emma, and Isshin himself.",
#  'Upon defeating them, Sekiro proceeds to betray Owl while Kuro realizes he has been corrupted by bloodlust, resulting in the "Shura" ending.',
#  'If Kuro is chosen, Sekiro fights and kills Owl.',
#  'Sekiro then enters the Divine Realm to collect the final material for the ritual.',
#  'Upon returning to Ashina, Sekiro discovers Isshin has succumbed to his illness and that the castle is under attack by the Interior Ministry.',
#  'Sekiro eventually finds Kuro under attack by Genichiro, who challenges Sekiro for the Dragon Heritage, only to be defeated once again.',
#  'Realizing Ashina is lost, Genichiro uses a ritual to revive Isshin in his prime so he might restore the clan, at the cost of his own life.',
#  "Although he disagrees with Genichiro's methods, Isshin honors his grandson's wish and fights Sekiro.",
#  'After defeating Isshin, there are three possible endings.',
#  'Performing the "Immortal Severance" ritual results in the eponymous standard ending, where the Dragon Heritage is removed at the cost of Kuro\'s life.',
#  'Afterward, like the Sculptor before him, Sekiro retires as a shinobi and spends the remainder of his days carving Buddha Statues.',
#  'Working with Emma to find an alternative way of severing immortality results in the "Purification" ending, where Sekiro sacrifices himself instead of Kuro.',
#  'The final ending, "Dragon\'s Homecoming", is obtained by helping a character known as the "Divine Child of the Rejuvenating Waters": Kuro\'s body dies, but his spirit lives on inside the Divine Child, who goes on a journey with Sekiro to return the Dragon Heritage to its origin place.',
#  "Development of Sekiro began in late 2015 following the completion of Bloodborne's downloadable content, The Old Hunters.",
#  '[10] The game was revealed via a teaser trailer at The Game Awards 2017 in December, showing the tagline "Shadows Die Twice".',
#  "[11] The game's full title was revealed to be Sekiro: Shadows Die Twice during Microsoft's press conference at E3 2018.",
#  'It was directed by Hidetaka Miyazaki of the Japanese development studio FromSoftware, best known for creating the Souls series and Bloodborne.',
#  '[12] The game was published by Activision worldwide, with FromSoftware self-publishing it in Japan and Cube Game publishing in the Asia-Pacific region.',
#  "[13][14] Sekiro's soundtrack was composed by Yuka Kitamura,[15] with some contributions from Noriyuki Asakura.",
#  'The game was released for PlayStation 4, Windows, and Xbox One on 22 March 2019.',
#  "[16] A collectors edition was also released the same day, and included a steelbook case, a figurine of the protagonist, an art book, a physical map of the game's world, a download code for the soundtrack, and in-game coin replicas.",
#  '[16] A port for Stadia was released in late 2020.',
#  '[17]\nSekiro draws inspiration from the Tenchu series of stealth-action games that were partially developed and published by FromSoftware.',
#  '[18] The team initially considered developing the game as a sequel to Tenchu.',
#  'However, as that series had already been shaped by several different studios before they obtained the rights to it, they instead opted to take the project in a different direction.',
#  '[10] Miyazaki intended the combat changes to capture the feel of "swords clashing", with fighters trying to create an opening to deliver the fatal strike.',
#  '[3] He and the team also created the game to be an entirely single-player experience, as they believed multiplayer to have limitations they wanted to avoid.',
#  '[6]\nThe word "sekirō" (隻狼) is a contraction of "sekiwan no ōkami" (隻腕の狼), which translates as "one-armed wolf.',
#  '"[19] The subtitle "Shadows Die Twice" was initially meant to be used as a slogan for the teaser trailer until Activision requested it be kept for the final name.',
#  '[3][20] Despite the game taking place during the Sengoku period of real-world Japanese history, no historical people or locations are featured in the game.',
#  '[21] On 31 October 2020, a free update was released that added new content to the game, such as new cosmetics for Wolf and a boss rush game mode.',
#  '[22]\nAccording to review aggregator Metacritic, Sekiro received "universal acclaim" for the PlayStation 4 and Xbox One versions, and "generally favorable" reviews for the Windows version.',
#  "[23][24][25] Many critics praised the game's combat for departing from the typical style of FromSoftware's other similar games.",
#  'In a review for Destructoid, Chris Carter described open combat as "akin to a waltz" and praised the variety of ways the combat could be approached, writing that players had more choices than in Dark Souls or Bloodborne.',
#  '[26] Brandin Tyrell from IGN praised the game\'s focus on "split-second swordsmanship", and despite the fact that "to any Souls veteran, Sekiro\'s timing-based lock-on combat of strikes and slashes is familiar", the game\'s "sense of safety" caused the combat to feel "refreshing and new".',
#  '[33] PC Gamer journalist Tom Senior called the combat "beautiful" and praised the posture system, writing that "instead of chipping down health bars until the enemy keels over, you overwhelm their posture bar with strikes and perfect parries until an opening appears, and then finish with a deathblow".',
#  '[38] He stated that the system takes "the catharsis" of beating a great boss and "focuses all that emotion into one split second".',
#  'In a review for website GameSpot, Tamoor Hussain wrote that the game "rewrites the rules of engagement", stating that, while previous FromSoftware games demanded quick decision-making, Sekiro "pushes these demands further" than ever before.',
#  'Reviewers also praised the resurrection mechanic, with Carter calling it "genius", and the stealth options, which gave the player freedom without descending into frustration.',
#  'The level design was also praised.',
#  'Particular emphasis was given to the increased verticality the player had due to the addition of the grappling hook and a dedicated jump button.',
#  'Tyrell wrote that the grappling hook "sends ripples throughout the gameplay", writing that "where all previous Soulsborne characters felt rooted firmly to the ground as they trudged down hallways and slowly climbed ladders, Sekiro\'s level design has permission to be much more vertical".',
#  'Carter wrote that the hook provided "a more vertical and in some cases more challenging level design from an exploration standpoint".',
#  'Senior wrote that the game used "large but separate zones rather than a huge connected world", but praised the "many secrets hidden just off the critical path, often reached with the excellent grappling hook, which lets you vault between tree branches and rooftops".',
#  'The levels themselves were also praised, with Hussain writing that "buildings are placed together to encourage exploration and reconnaissance, with roofs almost touching so that you can leap between them and scope out all angles", with the branching paths "creating that satisfying feeling of venturing into the unknown and then emerging into the familiar".',
#  '[31]\nReaction to the lack of online multiplayer was mixed.',
#  'Several reviewers noted that this allowed the game to have a full pause button, which was praised.',
#  'However, Tyrell noted that he "missed the small notes left by others in the world alerting me to imminent threats or hidden secrets, or that vague sense that danger lurks behind me in the form of an invading player" that defined the experience of playing "Soulsborne" games.',
#  'He also noticed the "lack of PvP battles, which seem[ed] like a waste of the new emphasis on skill-based swordsmanship", and argued that the parrying and blocking mechanics would have suited online play.',
#  "Similarly to other FromSoftware games, the game's high level of difficulty polarised players and journalists.",
#  'Several reviewers praised the difficulty, with Senior calling it "brutal" but "spectacular".',
#  'Hussain wrote that the game "punishes you for missteps" and was "suited for people of a certain temperament and with a very specific, slightly masochistic taste in games", but argued that victory was "intense" and "gratifying".',
#  'Tyrell wrote that the combat had a "steep curve to mastering it" but argued it was "somewhat easier than its predecessors", while still providing the sense of being "the greatest swordsman that ever lived" after tough victories.',
#  'However, several journalists found it to be too tough, with Don Rowe from The Spinoff calling it "infuriating", and writing that he was not having fun after six hours with the game.',
#  "[39] Forbes journalist Dave Thier criticized FromSoftware's decision to have one set difficulty on the game, claiming this made it inaccessible to players with a lower skill level.",
#  'He argued that the studio should "respect its players" and add an easier difficulty mode.',
#  "[40] Several days after the game was released, modders managed to develop mods which would make the game easier by changing the speed of the player's character relative to the game.",
#  "[41] James Davenport of PC Gamer said that the game's final boss was too difficult for him to beat without the help of the software.",
#  "[42]\nOn release day, Sekiro drew over 108,000 concurrent players on Steam, the highest for a new game launched during January–March 2019, and the third highest of any Japanese game in the platform's history, behind only Monster Hunter: World and Dark Souls III.",
#  '[43][44] Later in March, it had reached over 125,000 concurrent players on Steam, making it one of the most played games on the platform at the time.',
#  "[45] In its debut week, Sekiro topped both the UK and EMEAA (Europe, Middle East, Africa, Asia) charts, surpassing Tom Clancy's The Division 2.",
#  '[46][47][48] In Japan, the game debuted at first with 157,548 retail copies sold in its opening weekend.',
#  '[49] Within ten days of its release, over two\xa0million copies were sold worldwide, which rose to over five million by July 2020.',
#  '[50][51]\nThe game was nominated for and won several awards, including game of the year at The Game Awards 2019,[52] by editors of GameSpot,[53] and by fans in the 2019 Steam Awards.',
#  '[54]']

# %%
sentence_weights = {}
for sent in sentences:
    for key_words in word_frequecies:
        if key_words in sent:
            value = word_frequecies.get(key_words, 0)
            if sent in sentence_weights:
                sentence_weights[sent] += value
            else:
                sentence_weights[sent] = value

# %%
sentence_weights
# Out:
# {'\n\nSekiro: Shadows Die Twice[a] is a 2019 action-adventure game developed by FromSoftware and published by Activision.': 2.125,
#  'The game follows a shinobi known as Wolf as he attempts to take revenge on a samurai clan who attacked him and kidnapped his lord.': 1.8214285714285712,
#  'It was released for Microsoft Windows, PlayStation 4, and Xbox One in March 2019 and for Stadia in October 2020.': 1.0535714285714288,
#  'Gameplay is focused on stealth, exploration, and combat, with a particular emphasis on boss battles.': 0.7500000000000001,
#  'The game takes place in a fictionalized Japan during the Sengoku period and makes strong references to Buddhist mythology and philosophy.': 1.5714285714285712,
#  'While making the game, lead director Hidetaka Miyazaki wanted to create a new intellectual property (IP) that marked a departure from the Souls series of games also made by FromSoftware.': 2.0535714285714284,
#  'The developers looked to games such as The Mysterious Murasame Castle and the Tenchu series for inspiration.': 1.6071428571428572,
#  'Sekiro was praised by critics, who complimented its gameplay and setting, and compared it to the Souls games, although opinions on its difficulty were mixed.': 2.071428571428571,
#  'It was nominated for various awards and won several, including The Game Award for Game of the Year.': 0.9107142857142857,
#  'The game sold over five million copies by July 2020.': 1.4821428571428574,
#  'Sekiro: Shadows Die Twice is an action-adventure game played from a third-person view.': 1.6249999999999998,
#  "[1][2][3][4] Compared to FromSoftware's Souls series, the game features fewer role-playing elements, lacking character creation and the ability to level up a variety of stats, as well as having no multiplayer elements.": 2.7142857142857135,
#  '[3][4][5][6] It does, however, include gear upgrading, a skill tree, and limited ability customization.': 0.6607142857142858,
#  "Rather than attacking to whittle an enemy's health points, combat in Sekiro revolves around using a katana to attack their posture and balance instead, which eventually leads to an opening that allows for a single killing blow.": 2.0178571428571423,
#  '[3][7]\nThe game also features stealth elements, allowing players to instantly eliminate some enemies if they can get in range undetected.': 2.0,
#  '[3] In addition, the player character can use various tools to assist with combat and exploration, such as a grappling hook.': 1.0357142857142856,
#  '[3] If the player character dies, they have the option of being revived on the spot if they have resurrection power, which is restored by defeating enemies, instead of respawning at earlier checkpoints.': 0.9107142857142864,
#  '[3]\nFollowing the Sengoku period, Isshin Ashina seized control of the land of Ashina.': 0.6785714285714287,
#  '[1] During this time, a nameless orphan is adopted by the wandering shinobi known as "Owl", who named the boy "Wolf", and trained him in the ways of the shinobi.': 0.910714285714286,
#  'Two decades later, Ashina is on the brink of collapse due to the now elderly Isshin falling ill and the Interior Ministry, a group set on unifying Japan, steadily closing in.': 0.8750000000000003,
#  'Desperate to save his clan, Isshin\'s adoptive grandson Genichiro seeks the immortal "Divine Heir" Kuro in hopes of using the "Dragon Heritage" in his blood to create an immortal army.': 2.0178571428571423,
#  "Wolf, now a full-fledged shinobi and Kuro's personal bodyguard, fights Genichiro but loses the duel along with his left arm while Genichiro takes the boy.": 1.7857142857142851,
#  'However, being immortal himself, Wolf survives and is found by a retired shinobi known as the "Sculpter", who nurses him \nback to health and gifts him a Shinobi Prosthetic.': 0.9285714285714288,
#  "[3][8][9]\nTo rescue Kuro, Wolf assaults Ashina Castle whilst being forced to confront his own past: three years ago, Kuro's birthplace, the Hirata estate, was raided by bandits led by Wolf's former teacher, Lady Butterfly, who was attempting to kidnap Kuro.": 1.9999999999999987,
#  "While Wolf was able to defeat her, he was then stabbed in the back by an unknown assailant but survived thanks to Kuro making him immortal through the Dragon's Heritage.": 1.910714285714285,
#  'Back in the present, Wolf once again confronts Genichiro and this time, defeats him.': 0.5178571428571428,
#  'However, Genichiro survives by drinking an artificial replication of the Dragon Heritage known as the "Rejuvenating Waters", and flees.': 0.9285714285714287,
#  'Kuro then asks Wolf to perform the "Immortal Severance" ritual, which would result in Kuro\'s death and prevent anyone from fighting over his immortality.': 1.6607142857142856,
#  'Wolf reluctantly agrees to help and sets out to collect the necessary materials for the ritual.': 0.5357142857142857,
#  'Wolf\'s quest also leads him to cross paths with Isshin, who gives him a new name: "Sekiro", the "one-armed wolf".': 2.1607142857142856,
#  'After collecting all the components for the ritual, Sekiro is confronted by Owl, who was thought to have been killed during the raid on Hirata and revealed to be the one who back-stabbed Sekiro back then.': 1.2678571428571428,
#  'Owl reveals he also seeks the Dragon Heritage and orders Sekiro to renounce his loyalty to Kuro.': 1.5357142857142854,
#  "If Sekiro sides with Owl, he is forced to fight Isshin's doctor, Emma, and Isshin himself.": 1.5714285714285716,
#  'Upon defeating them, Sekiro proceeds to betray Owl while Kuro realizes he has been corrupted by bloodlust, resulting in the "Shura" ending.': 1.2499999999999996,
#  'If Kuro is chosen, Sekiro fights and kills Owl.': 1.0714285714285714,
#  'Sekiro then enters the Divine Realm to collect the final material for the ritual.': 0.8571428571428572,
#  'Upon returning to Ashina, Sekiro discovers Isshin has succumbed to his illness and that the castle is under attack by the Interior Ministry.': 1.2321428571428572,
#  'Sekiro eventually finds Kuro under attack by Genichiro, who challenges Sekiro for the Dragon Heritage, only to be defeated once again.': 1.4821428571428565,
#  'Realizing Ashina is lost, Genichiro uses a ritual to revive Isshin in his prime so he might restore the clan, at the cost of his own life.': 0.8392857142857145,
#  "Although he disagrees with Genichiro's methods, Isshin honors his grandson's wish and fights Sekiro.": 1.6607142857142856,
#  'After defeating Isshin, there are three possible endings.': 0.4642857142857142,
#  'Performing the "Immortal Severance" ritual results in the eponymous standard ending, where the Dragon Heritage is removed at the cost of Kuro\'s life.': 1.7142857142857142,
#  'Afterward, like the Sculptor before him, Sekiro retires as a shinobi and spends the remainder of his days carving Buddha Statues.': 0.9642857142857146,
#  'Working with Emma to find an alternative way of severing immortality results in the "Purification" ending, where Sekiro sacrifices himself instead of Kuro.': 1.3035714285714284,
#  'The final ending, "Dragon\'s Homecoming", is obtained by helping a character known as the "Divine Child of the Rejuvenating Waters": Kuro\'s body dies, but his spirit lives on inside the Divine Child, who goes on a journey with Sekiro to return the Dragon Heritage to its origin place.': 2.999999999999999,
#  "Development of Sekiro began in late 2015 following the completion of Bloodborne's downloadable content, The Old Hunters.": 1.9642857142857135,
#  '[10] The game was revealed via a teaser trailer at The Game Awards 2017 in December, showing the tagline "Shadows Die Twice".': 1.9642857142857142,
#  "[11] The game's full title was revealed to be Sekiro: Shadows Die Twice during Microsoft's press conference at E3 2018.": 2.999999999999999,
#  'It was directed by Hidetaka Miyazaki of the Japanese development studio FromSoftware, best known for creating the Souls series and Bloodborne.': 1.0178571428571428,
#  '[12] The game was published by Activision worldwide, with FromSoftware self-publishing it in Japan and Cube Game publishing in the Asia-Pacific region.': 1.8749999999999998,
#  "[13][14] Sekiro's soundtrack was composed by Yuka Kitamura,[15] with some contributions from Noriyuki Asakura.": 1.6428571428571423,
#  'The game was released for PlayStation 4, Windows, and Xbox One on 22 March 2019.': 1.910714285714286,
#  "[16] A collectors edition was also released the same day, and included a steelbook case, a figurine of the protagonist, an art book, a physical map of the game's world, a download code for the soundtrack, and in-game coin replicas.": 2.2142857142857135,
#  '[16] A port for Stadia was released in late 2020.': 0.5357142857142856,
#  '[17]\nSekiro draws inspiration from the Tenchu series of stealth-action games that were partially developed and published by FromSoftware.': 2.0714285714285716,
#  '[18] The team initially considered developing the game as a sequel to Tenchu.': 1.375,
#  'However, as that series had already been shaped by several different studios before they obtained the rights to it, they instead opted to take the project in a different direction.': 0.6785714285714288,
#  '[10] Miyazaki intended the combat changes to capture the feel of "swords clashing", with fighters trying to create an opening to deliver the fatal strike.': 0.7500000000000004,
#  '[3] He and the team also created the game to be an entirely single-player experience, as they believed multiplayer to have limitations they wanted to avoid.': 1.5714285714285712,
#  '[6]\nThe word "sekirō" (隻狼) is a contraction of "sekiwan no ōkami" (隻腕の狼), which translates as "one-armed wolf.': 0.8035714285714289,
#  '"[19] The subtitle "Shadows Die Twice" was initially meant to be used as a slogan for the teaser trailer until Activision requested it be kept for the final name.': 1.2499999999999998,
#  '[3][20] Despite the game taking place during the Sengoku period of real-world Japanese history, no historical people or locations are featured in the game.': 1.4464285714285712,
#  '[21] On 31 October 2020, a free update was released that added new content to the game, such as new cosmetics for Wolf and a boss rush game mode.': 1.9107142857142858,
#  '[22]\nAccording to review aggregator Metacritic, Sekiro received "universal acclaim" for the PlayStation 4 and Xbox One versions, and "generally favorable" reviews for the Windows version.': 1.2678571428571423,
#  "[23][24][25] Many critics praised the game's combat for departing from the typical style of FromSoftware's other similar games.": 2.517857142857143,
#  'In a review for Destructoid, Chris Carter described open combat as "akin to a waltz" and praised the variety of ways the combat could be approached, writing that players had more choices than in Dark Souls or Bloodborne.': 1.4464285714285707,
#  '[26] Brandin Tyrell from IGN praised the game\'s focus on "split-second swordsmanship", and despite the fact that "to any Souls veteran, Sekiro\'s timing-based lock-on combat of strikes and slashes is familiar", the game\'s "sense of safety" caused the combat to feel "refreshing and new".': 3.1785714285714266,
#  '[33] PC Gamer journalist Tom Senior called the combat "beautiful" and praised the posture system, writing that "instead of chipping down health bars until the enemy keels over, you overwhelm their posture bar with strikes and perfect parries until an opening appears, and then finish with a deathblow".': 1.6607142857142854,
#  '[38] He stated that the system takes "the catharsis" of beating a great boss and "focuses all that emotion into one split second".': 0.7678571428571433,
#  'In a review for website GameSpot, Tamoor Hussain wrote that the game "rewrites the rules of engagement", stating that, while previous FromSoftware games demanded quick decision-making, Sekiro "pushes these demands further" than ever before.': 2.374999999999999,
#  'Reviewers also praised the resurrection mechanic, with Carter calling it "genius", and the stealth options, which gave the player freedom without descending into frustration.': 1.035714285714286,
#  'The level design was also praised.': 0.9642857142857143,
#  'Particular emphasis was given to the increased verticality the player had due to the addition of the grappling hook and a dedicated jump button.': 0.6428571428571429,
#  'Tyrell wrote that the grappling hook "sends ripples throughout the gameplay", writing that "where all previous Soulsborne characters felt rooted firmly to the ground as they trudged down hallways and slowly climbed ladders, Sekiro\'s level design has permission to be much more vertical".': 3.0892857142857135,
#  'Carter wrote that the hook provided "a more vertical and in some cases more challenging level design from an exploration standpoint".': 0.642857142857143,
#  'Senior wrote that the game used "large but separate zones rather than a huge connected world", but praised the "many secrets hidden just off the critical path, often reached with the excellent grappling hook, which lets you vault between tree branches and rooftops".': 1.8214285714285707,
#  'The levels themselves were also praised, with Hussain writing that "buildings are placed together to encourage exploration and reconnaissance, with roofs almost touching so that you can leap between them and scope out all angles", with the branching paths "creating that satisfying feeling of venturing into the unknown and then emerging into the familiar".': 1.8035714285714277,
#  '[31]\nReaction to the lack of online multiplayer was mixed.': 0.5535714285714286,
#  'Several reviewers noted that this allowed the game to have a full pause button, which was praised.': 1.2500000000000002,
#  'However, Tyrell noted that he "missed the small notes left by others in the world alerting me to imminent threats or hidden secrets, or that vague sense that danger lurks behind me in the form of an invading player" that defined the experience of playing "Soulsborne" games.': 1.9285714285714284,
#  'He also noticed the "lack of PvP battles, which seem[ed] like a waste of the new emphasis on skill-based swordsmanship", and argued that the parrying and blocking mechanics would have suited online play.': 1.0714285714285718,
#  "Similarly to other FromSoftware games, the game's high level of difficulty polarised players and journalists.": 2.2142857142857135,
#  'Several reviewers praised the difficulty, with Senior calling it "brutal" but "spectacular".': 0.6607142857142858,
#  'Hussain wrote that the game "punishes you for missteps" and was "suited for people of a certain temperament and with a very specific, slightly masochistic taste in games", but argued that victory was "intense" and "gratifying".': 1.3928571428571421,
#  'Tyrell wrote that the combat had a "steep curve to mastering it" but argued it was "somewhat easier than its predecessors", while still providing the sense of being "the greatest swordsman that ever lived" after tough victories.': 0.9107142857142863,
#  'However, several journalists found it to be too tough, with Don Rowe from The Spinoff calling it "infuriating", and writing that he was not having fun after six hours with the game.': 1.6964285714285714,
#  "[39] Forbes journalist Dave Thier criticized FromSoftware's decision to have one set difficulty on the game, claiming this made it inaccessible to players with a lower skill level.": 2.4821428571428563,
#  'He argued that the studio should "respect its players" and add an easier difficulty mode.': 0.6785714285714288,
#  "[40] Several days after the game was released, modders managed to develop mods which would make the game easier by changing the speed of the player's character relative to the game.": 2.160714285714285,
#  "[41] James Davenport of PC Gamer said that the game's final boss was too difficult for him to beat without the help of the software.": 1.9107142857142854,
#  "[42]\nOn release day, Sekiro drew over 108,000 concurrent players on Steam, the highest for a new game launched during January–March 2019, and the third highest of any Japanese game in the platform's history, behind only Monster Hunter: World and Dark Souls III.": 3.4642857142857113,
#  '[43][44] Later in March, it had reached over 125,000 concurrent players on Steam, making it one of the most played games on the platform at the time.': 2.0714285714285716,
#  "[45] In its debut week, Sekiro topped both the UK and EMEAA (Europe, Middle East, Africa, Asia) charts, surpassing Tom Clancy's The Division 2.": 2.124999999999999,
#  '[46][47][48] In Japan, the game debuted at first with 157,548 retail copies sold in its opening weekend.': 1.482142857142856,
#  '[49] Within ten days of its release, over two\xa0million copies were sold worldwide, which rose to over five million by July 2020.': 0.8035714285714287,
#  '[50][51]\nThe game was nominated for and won several awards, including game of the year at The Game Awards 2019,[52] by editors of GameSpot,[53] and by fans in the 2019 Steam Awards.': 2.1785714285714284,
#  '[54]': 0.125}

# %%
select_lenght = int(len(sentences) * 0.30)

summary = nlargest(select_lenght, sentence_weights, key=sentence_weights.get)

# %%
# Rearranging the summary so, we can have structured sentences

new_summary = []
for sent in sentences:
    if sent in summary:
        new_summary.append(sent)
        
final_summary = " ".join([word for word in new_summary])

# %%
print(final_summary)
# Out:
# Sekiro: Shadows Die Twice[a] is a 2019 action-adventure game developed by FromSoftware and published by Activision. While making the game, lead director Hidetaka Miyazaki wanted to create a new intellectual property (IP) that marked a departure from the Souls series of games also made by FromSoftware. Sekiro was praised by critics, who complimented its gameplay and setting, and compared it to the Souls games, although opinions on its difficulty were mixed. [1][2][3][4] Compared to FromSoftware's Souls series, the game features fewer role-playing elements, lacking character creation and the ability to level up a variety of stats, as well as having no multiplayer elements. Rather than attacking to whittle an enemy's health points, combat in Sekiro revolves around using a katana to attack their posture and balance instead, which eventually leads to an opening that allows for a single killing blow. [3][7]
# The game also features stealth elements, allowing players to instantly eliminate some enemies if they can get in range undetected. Desperate to save his clan, Isshin's adoptive grandson Genichiro seeks the immortal "Divine Heir" Kuro in hopes of using the "Dragon Heritage" in his blood to create an immortal army. [3][8][9]
# To rescue Kuro, Wolf assaults Ashina Castle whilst being forced to confront his own past: three years ago, Kuro's birthplace, the Hirata estate, was raided by bandits led by Wolf's former teacher, Lady Butterfly, who was attempting to kidnap Kuro. Wolf's quest also leads him to cross paths with Isshin, who gives him a new name: "Sekiro", the "one-armed wolf". The final ending, "Dragon's Homecoming", is obtained by helping a character known as the "Divine Child of the Rejuvenating Waters": Kuro's body dies, but his spirit lives on inside the Divine Child, who goes on a journey with Sekiro to return the Dragon Heritage to its origin place. Development of Sekiro began in late 2015 following the completion of Bloodborne's downloadable content, The Old Hunters. [10] The game was revealed via a teaser trailer at The Game Awards 2017 in December, showing the tagline "Shadows Die Twice". [11] The game's full title was revealed to be Sekiro: Shadows Die Twice during Microsoft's press conference at E3 2018. The game was released for PlayStation 4, Windows, and Xbox One on 22 March 2019. [16] A collectors edition was also released the same day, and included a steelbook case, a figurine of the protagonist, an art book, a physical map of the game's world, a download code for the soundtrack, and in-game coin replicas. [17]
# Sekiro draws inspiration from the Tenchu series of stealth-action games that were partially developed and published by FromSoftware. [21] On 31 October 2020, a free update was released that added new content to the game, such as new cosmetics for Wolf and a boss rush game mode. [23][24][25] Many critics praised the game's combat for departing from the typical style of FromSoftware's other similar games. [26] Brandin Tyrell from IGN praised the game's focus on "split-second swordsmanship", and despite the fact that "to any Souls veteran, Sekiro's timing-based lock-on combat of strikes and slashes is familiar", the game's "sense of safety" caused the combat to feel "refreshing and new". In a review for website GameSpot, Tamoor Hussain wrote that the game "rewrites the rules of engagement", stating that, while previous FromSoftware games demanded quick decision-making, Sekiro "pushes these demands further" than ever before. Tyrell wrote that the grappling hook "sends ripples throughout the gameplay", writing that "where all previous Soulsborne characters felt rooted firmly to the ground as they trudged down hallways and slowly climbed ladders, Sekiro's level design has permission to be much more vertical". However, Tyrell noted that he "missed the small notes left by others in the world alerting me to imminent threats or hidden secrets, or that vague sense that danger lurks behind me in the form of an invading player" that defined the experience of playing "Soulsborne" games. Similarly to other FromSoftware games, the game's high level of difficulty polarised players and journalists. [39] Forbes journalist Dave Thier criticized FromSoftware's decision to have one set difficulty on the game, claiming this made it inaccessible to players with a lower skill level. [40] Several days after the game was released, modders managed to develop mods which would make the game easier by changing the speed of the player's character relative to the game. [42]
# On release day, Sekiro drew over 108,000 concurrent players on Steam, the highest for a new game launched during January–March 2019, and the third highest of any Japanese game in the platform's history, behind only Monster Hunter: World and Dark Souls III. [43][44] Later in March, it had reached over 125,000 concurrent players on Steam, making it one of the most played games on the platform at the time. [45] In its debut week, Sekiro topped both the UK and EMEAA (Europe, Middle East, Africa, Asia) charts, surpassing Tom Clancy's The Division 2. [50][51]
# The game was nominated for and won several awards, including game of the year at The Game Awards 2019,[52] by editors of GameSpot,[53] and by fans in the 2019 Steam Awards.

# %% [markdown]
# ### Creating the function

# %%
def SummarizeText():
    link = input("Please paste/type the wikipedia link: \n")
    percent = float(input("\nHow short do you want to summarize the page? (0.0 - 1.0): \n"))
    content = requests.get(link).text
    article = BeautifulSoup(content, 'lxml')
    article_content = ""
    for paragraph in article.find_all('p'):
        article_content += paragraph.text
        
    punctuation_ = punctuation + '\n'
    stop_words = stopwords.words('english')
    text_ = [word for word in nltk.word_tokenize(article_content) if word not in punctuation_ and word not in stop_words]
    word_frequecies = {}
    for word in text_:
        if word in word_frequecies:
            word_frequecies[word] += 1
        else:
            word_frequecies[word] = 1
    
    max_value = max(word_frequecies.values())
    
    for k, v in word_frequecies.items():
        word_frequecies[k] = v / max_value
        
    sentences = nltk.sent_tokenize(article_content)
    
    sentence_weights = {}
    for sent in sentences:
        for key_words in word_frequecies:
            if key_words in sent:
                value = word_frequecies.get(key_words, 0)
                if sent in sentence_weights:
                    sentence_weights[sent] += value
                else:
                    sentence_weights[sent] = value
                    
    select_lenght = int(len(sentences)*percent)
    
    summary = nlargest(select_lenght, sentence_weights, key=sentence_weights.get)
    
    new_summary = []
    for sent in sentences:
        if sent in summary:
            new_summary.append(sent)
        
    final_summary = " ".join([word for word in new_summary])
    
    print("\n\n"," "*50, "SUMMARIZED TEXT")
    print("="*120)
    print(final_summary)
    print("\n","="*120)

# %%
SummarizeText()
# Out:
# Please paste/type the wikipedia link:
# https://en.wikipedia.org/wiki/Boat
#
# How short do you want to summarize the page? (0.0 - 1.0):
# 0.3
#
#
#                                                     SUMMARIZED TEXT
# ========================================================================================================================
#
# A boat is a watercraft of a large range of types and sizes, but generally smaller than a ship, which is distinguished by its larger size, shape, cargo or passenger capacity, or its ability to carry boats. Small boats are typically found on inland waterways such as rivers and lakes, or in protected coastal areas. Pleasure craft used in recreational boating include ski boats, pontoon boats, and sailboats. After the Homo erectus possibly using watercrafts more than a million years ago crossing straits between landmasses,[2][3] boats have served as transportation far into the pre-historic. [4]  Circumstantial evidence, such as the early settlement of Australia over 40,000 years ago, findings in Crete dated 130,000 years ago,[5] and in Flores dated to 900,000 years ago,[6] suggest that boats have been used since prehistoric times. The earliest boats are thought to have been dugouts,[7][dubious  – discuss] and the oldest boats found by archaeological excavation date from around 7,000–10,000 years ago. [16] Evidence of varying models of boats has also been discovered at various Indus Valley archaeological sites. The ancient Arabs and Greeks used such boats as trading vessels. [19]
# The historians Herodotus, Pliny the Elder and Strabo record the use of boats for commerce, travel, and military purposes. [17]
# Boats can be categorized into three main types:
# A number of large vessels are usually referred to as boats. [20]  Other types of large vessels which are traditionally called boats include Great Lakes freighters, riverboats, and ferryboats. [21] Though large enough to carry their own boats and heavy cargoes, these vessels are designed for operation on inland or protected coastal waters. Until the mid-19th century most boats were made of natural materials, primarily wood, although reed, bark and animal skins were also used. Early boats include the bound-reed style of boat seen in Ancient Egypt, the birch bark canoe, the animal hide-covered kayak[22] and coracle and the dugout canoe made from a single log. By the mid-19th century, many boats had been built with iron or steel frames but still planked in wood. [citation needed]
# As the forests of Britain and Europe continued to be over-harvested to supply the keels of larger wooden boats, and the Bessemer process (patented in 1855) cheapened the cost of steel, steel ships and boats began to be more common. By the 1930s boats built entirely of steel from frames to plating were seen replacing wooden boats in many industrial uses and fishing fleets. In 1895 WH Mullins produced steel boats of galvanized iron and by 1930 became the world's largest producer of pleasure boats. Mullins also offered boats in aluminum from 1895 through 1899 and once again in the 1920s,[23] but it wasn't until the mid-20th century that aluminium gained widespread popularity. Around the mid-1960s, boats made of fiberglass (aka "glassfibre") became popular, especially for recreational boats. Since 1998 all new leisure boats and barges built in Europe between 2.5m and 24m must comply with the EU's Recreational Craft Directive (RCD).
#
#  ========================================================================================================================
