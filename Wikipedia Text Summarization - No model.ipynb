# %% [markdown]
# ## Text Summarization
# by: Jeremiah Chinyelugo

# %%
import requests
from bs4 import BeautifulSoup
import re
import nltk
from string import punctuation
from nltk.corpus import stopwords
from heapq import nlargest

# %%
content = requests.get("https://en.wikipedia.org/wiki/Sekiro:_Shadows_Die_Twice").text

# %%
print(content[:1000])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Sekiro: Shadows Die Twice - Wikipedia</title>
# <script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"80556b85-c144-4fd6-9557-3757a3de6197","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Sekiro:_Shadows_Die_Twice","wgTitle":"Sekiro: Shadows Die Twice","wgCurRevisionId":1108418109,"wgRevisionId":1108418109,"wgArticleId":57651025,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles containing Japanese-language text","CS1 Japanese-language sources (ja)","CS1 uses Chinese-language script (

# %%
article = BeautifulSoup(content, 'lxml')

# %%
article_content = ""
for paragraph in article.find_all('p'):
    article_content += paragraph.text

# %%
print(article_content)
# Out:
# Sekiro: Shadows Die Twice[a] is a 2019 action-adventure game developed by FromSoftware and published by Activision. The game follows a shinobi known as Wolf as he attempts to take revenge on a samurai clan who attacked him and kidnapped his lord. It was released for PlayStation 4, Windows, and Xbox One in March 2019 and for Stadia in October 2020.
# Gameplay is focused on stealth, exploration, and combat, with a particular emphasis on boss battles. The game takes place in a fictionalized Japan during the Sengoku period and makes strong references to Buddhist mythology and philosophy. While making the game, lead director Hidetaka Miyazaki wanted to create a new intellectual property (IP) that marked a departure from the Dark Souls series of games also made by FromSoftware. The developers looked to games such as the Tenchu series for inspiration.
# Sekiro was praised by critics, who complimented its gameplay and setting, and compared it to the Dark Souls games, although opinions on its difficulty were mixed. It was nominated for various awards and won several, including The Game Award for Game of the Year. The game sold over five million copies by July 2020.
# Sekiro: Shadows Die Twice is an action-adventure game played from a third-person view.[1][2][3][4] Compared to FromSoftware's Dark Souls series, the game features fewer role-playing elements, lacking character creation and the ability to level up a variety of stats, as well as having no multiplayer elements.[3][4][5][6] It does, however, include gear upgrading, a skill tree, and limited ability customization. Rather than attacking to whittle an enemy's health points, combat in Sekiro revolves around using a katana to attack their posture and balance instead, which eventually leads to an opening that allows for a single killing blow.[3][7]
# The game also features stealth elements, allowing players to instantly eliminate some enemies if they can get in range undetected.[3] In addition, the player character can use various tools to assist with combat and exploration, such as a grappling hook.[3] If the player character dies, they have the option of being revived on the spot if they have resurrection power, which is restored by defeating enemies, instead of respawning at earlier checkpoints.[3]
# Following the Sengoku period, Isshin Ashina seized control of the land of Ashina. During this time, a nameless orphan is adopted by the wandering shinobi known as Owl, who named the boy Wolf, and trained him in the ways of the shinobi. Two decades later, Ashina is on the brink of collapse due to the now elderly Isshin falling ill and the Interior Ministry, a group set on unifying Japan, steadily closing in. Desperate to save his clan, Isshin's adoptive grandson Genichiro seeks the immortal Divine Heir Kuro in hopes of using the Dragon Heritage in his blood to create an immortal army. Wolf, now a full-fledged shinobi and Kuro's personal bodyguard, fights Genichiro but loses both Kuro and his left arm. However, being immortal himself, Wolf survives and is found by a retired shinobi known as the Sculptor. The Sculptor nurses Wolf back to health and gifts him a prosthetic arm.
# To rescue Kuro, Wolf assaults Ashina Castle whilst being forced to confront his own past; Three years ago, Kuro's birthplace, the Hirata estate, was raided by bandits led by Wolf's former teacher, Lady Butterfly. While Wolf was able to defeat her, he was then stabbed in the back by an unknown assailant, but survived after Kuro made him immortal using the Dragon Heritage. Back in the present, Wolf once again confronts Genichiro and this time, defeats him. However, Genichiro survives by drinking an artificial replication of the Dragon Heritage known as the Rejuvenating Waters and flees. Kuro asks Wolf to perform the Immortal Severance ritual, which would result in Kuro's death and prevent anyone from fighting over his immortality. Wolf reluctantly agrees and sets out to collect the necessary materials for the ritual. Wolf's quest leads him to cross paths with Isshin, who gives him a new name: Sekiro, the "one-armed wolf".
# After collecting all the components for the ritual, Sekiro is confronted by Owl, who is revealed to be the assailant who back-stabbed Sekiro at the Hirata estate. Owl reveals he also seeks the Dragon Heritage and orders Sekiro to renounce his loyalty to Kuro. If Sekiro sides with Owl, he is forced to fight Isshin's doctor, Emma, and Isshin himself. Upon defeating them, Sekiro proceeds to betray Owl while Kuro realizes he has been corrupted by bloodlust, resulting in the "Shura" ending. If Kuro is chosen, Sekiro fights and kills Owl. Sekiro then enters the Divine Realm to collect the final material for the ritual. Upon returning to Ashina, Sekiro discovers Isshin has succumbed to his illness and that the castle is under attack by the Interior Ministry. Sekiro eventually finds Kuro under attack by Genichiro, who he defeats once again. Realizing Ashina is lost, Genichiro sacrifices himself in a ritual to revive Isshin in his prime so that he might restore Ashina. Isshin honors his grandson's wish and fights Sekiro.
# After defeating Isshin, there are three possible endings. Performing the Immortal Severance ritual results in the eponymous standard ending, where the Dragon Heritage is removed at the cost of Kuro's life. Afterward, like the Sculptor before him, Sekiro retires as a shinobi and spends the remainder of his days carving Buddha Statues. Working with Emma to find an alternative way of severing immortality results in the Purification ending, where Sekiro sacrifices himself instead of Kuro. The final ending, Dragon's Homecoming, is obtained by helping a character known as the Divine Child of the Rejuvenating Waters. Kuro's body dies, but his spirit lives on inside the Divine Child, who goes on a journey with Sekiro to return the Dragon Heritage to its origin place.
# Development of Sekiro began in late 2015 following the completion of Bloodborne's downloadable content, The Old Hunters.[8] It was directed by Hidetaka Miyazaki, who had previously worked on the Dark Souls series and Bloodborne.[9] Sekiro draws inspiration from the Tenchu series of stealth-action games that were partially developed and published by FromSoftware.[10] The team initially considered developing the game as a sequel to Tenchu; however, it quickly outgrew the concept.[11] Miyazaki intended the combat changes to capture the feel of "swords clashing", with fighters trying to create an opening to deliver the fatal strike.[3] He and the team also created the game to be an entirely single-player experience, as they believed multiplayer to have limitations they wanted to avoid.[6] Despite the game taking place during the Sengoku period of real-world Japanese history, no historical people or locations are featured in the game.[12]
# The game was revealed via a teaser trailer at The Game Awards 2017 in December, showing the tagline "Shadows Die Twice".[13] The game's full title was revealed to be Sekiro: Shadows Die Twice during Microsoft's press conference at E3 2018.The game was published by Activision worldwide, with FromSoftware self-publishing it in Japan and Cube Game publishing in the Asia-Pacific region.[14][15] Sekiro's soundtrack was composed by Yuka Kitamura,[16] with some contributions from Noriyuki Asakura. The game was released for PlayStation 4, Windows, and Xbox One on 22 March 2019.[17] A collectors edition was also released the same day, and included a steelbook case, a figurine of the protagonist, an art book, a physical map of the game's world, a download code for the soundtrack, and in-game coin replicas.[17] A port for Stadia was released in late 2020.[18] On 31 October 2020, a free update was released that added new content to the game, such as new cosmetics for Wolf and a boss rush game mode.[19]
# The word "sekirō" (隻狼) is a contraction of "sekiwan no ōkami" (隻腕の狼), which translates as "one-armed wolf."[20] The subtitle "Shadows Die Twice" was initially meant to be used as a slogan for the teaser trailer until Activision requested it be kept for the final name.[3][21]
# According to review aggregator Metacritic, Sekiro received "universal acclaim" for the PlayStation 4 and Xbox One versions, and "generally favorable" reviews for the Windows version.[22][23][24] Many critics praised the game's combat for departing from the typical style of FromSoftware's other similar games. In a review for Destructoid, Chris Carter described open combat as "akin to a waltz" and praised the variety of ways the combat could be approached, writing that players had more choices than in Dark Souls or Bloodborne.[25] Brandin Tyrell from IGN praised the game's focus on "split-second swordsmanship", and despite the fact that "to any Souls veteran, Sekiro's timing-based lock-on combat of strikes and slashes is familiar", the game's "sense of safety" caused the combat to feel "refreshing and new".[32] PC Gamer journalist Tom Senior called the combat "beautiful" and praised the posture system, writing that "instead of chipping down health bars until the enemy keels over, you overwhelm their posture bar with strikes and perfect parries until an opening appears, and then finish with a deathblow".[37] He stated that the system takes "the catharsis" of beating a great boss and "focuses all that emotion into one split second". In a review for website GameSpot, Tamoor Hussain wrote that the game "rewrites the rules of engagement", stating that, while previous FromSoftware games demanded quick decision-making, Sekiro "pushes these demands further" than ever before. Reviewers also praised the resurrection mechanic, with Carter calling it "genius", and the stealth options, which gave the player freedom without descending into frustration.
# The level design was also praised. Particular emphasis was given to the increased verticality the player had due to the addition of the grappling hook and a dedicated jump button. Tyrell wrote that the grappling hook "sends ripples throughout the gameplay", writing that "where all previous Soulsborne characters felt rooted firmly to the ground as they trudged down hallways and slowly climbed ladders, Sekiro's level design has permission to be much more vertical". Carter wrote that the hook provided "a more vertical and in some cases more challenging level design from an exploration standpoint". Senior wrote that the game used "large but separate zones rather than a huge connected world", but praised the "many secrets hidden just off the critical path, often reached with the excellent grappling hook, which lets you vault between tree branches and rooftops". The levels themselves were also praised, with Hussain writing that "buildings are placed together to encourage exploration and reconnaissance, with roofs almost touching so that you can leap between them and scope out all angles", with the branching paths "creating that satisfying feeling of venturing into the unknown and then emerging into the familiar".[30]
# Reaction to the lack of online multiplayer was mixed. Several reviewers noted that this allowed the game to have a full pause button, which was praised. However, Tyrell noted that he "missed the small notes left by others in the world alerting me to imminent threats or hidden secrets, or that vague sense that danger lurks behind me in the form of an invading player" that defined the experience of playing "Soulsborne" games. He also noticed the "lack of PvP battles, which seem[ed] like a waste of the new emphasis on skill-based swordsmanship", and argued that the parrying and blocking mechanics would have suited online play.
# Similarly to other FromSoftware games, the game's high level of difficulty polarised players and journalists. Several reviewers praised the difficulty, with Senior calling it "brutal" but "spectacular". Hussain wrote that the game "punishes you for missteps" and was "suited for people of a certain temperament and with a very specific, slightly masochistic taste in games", but argued that victory was "intense" and "gratifying". Tyrell wrote that the combat had a "steep curve to mastering it" but argued it was "somewhat easier than its predecessors", while still providing the sense of being "the greatest swordsman that ever lived" after tough victories. However, several journalists found it to be too tough, with Don Rowe from The Spinoff calling it "infuriating", and writing that he was not having fun after six hours with the game.[38] Several days after the game was released, modders managed to develop mods which would make the game easier by changing the speed of the player's character relative to the game.[39] James Davenport of PC Gamer said that the game's final boss was too difficult for him to beat without the help of the software.[40]
# On release day, Sekiro drew over 108,000 concurrent players on Steam, the highest for a new game launched during January–March 2019, and the third highest of any Japanese game in the platform's history, behind only Monster Hunter: World and Dark Souls III.[41][42] Later in March, it had reached over 125,000 concurrent players on Steam, making it one of the most played games on the platform at the time.[43] In its debut week, Sekiro topped both the UK and EMEAA (Europe, Middle East, Africa, Asia) charts, surpassing Tom Clancy's The Division 2.[44][45][46] In Japan, the game debuted at first with 157,548 retail copies sold in its opening weekend.[47] Within ten days of its release, over two million copies were sold worldwide, which rose to over five million by July 2020.[48][49]
# The game was nominated for and won several awards, including game of the year at The Game Awards 2019,[50] by editors of GameSpot,[51] and by fans in the 2019 Steam Awards.[52]

# %%
punctuation_ = punctuation + '\n'
stop_words = stopwords.words('english')

# %%
# Create Frequency table, excluse stopwords and punctuations

def FrequecyTable(text):
    text = nltk.word_tokenize(text)
    text = [word for word in text if word not in punctuation_ and word not in stop_words]
    table = {}
    for word in text:
        if word in table:
            table[word] += 1
        else:
            table[word] = 1
    return table

# %%
word_frequecies = FrequecyTable(article_content)
word_frequecies
# Out:
# {'Sekiro': 28,
#  'Shadows': 5,
#  'Die': 5,
#  'Twice': 5,
#  '2019': 6,
#  'action-adventure': 2,
#  'game': 37,
#  'developed': 2,
#  'FromSoftware': 8,
#  'published': 3,
#  'Activision': 3,
#  'The': 22,
#  'follows': 1,
#  'shinobi': 6,
#  'known': 5,
#  'Wolf': 13,
#  'attempts': 1,
#  'take': 1,
#  'revenge': 1,
#  'samurai': 1,
#  'clan': 2,
#  'attacked': 1,
#  'kidnapped': 1,
#  'lord': 1,
#  'It': 4,
#  'released': 6,
#  'PlayStation': 3,
#  '4': 5,
#  'Windows': 3,
#  'Xbox': 3,
#  'One': 3,
#  'March': 3,
#  'Stadia': 2,
#  'October': 2,
#  '2020': 5,
#  'Gameplay': 1,
#  'focused': 1,
#  'stealth': 3,
#  'exploration': 4,
#  'combat': 11,
#  'particular': 1,
#  'emphasis': 3,
#  'boss': 4,
#  'battles': 2,
#  'takes': 2,
#  'place': 3,
#  'fictionalized': 1,
#  'Japan': 4,
#  'Sengoku': 3,
#  'period': 3,
#  'makes': 1,
#  'strong': 1,
#  'references': 1,
#  'Buddhist': 1,
#  'mythology': 1,
#  'philosophy': 1,
#  'While': 2,
#  'making': 2,
#  'lead': 1,
#  'director': 1,
#  'Hidetaka': 2,
#  'Miyazaki': 3,
#  'wanted': 2,
#  'create': 3,
#  'new': 7,
#  'intellectual': 1,
#  'property': 1,
#  'IP': 1,
#  'marked': 1,
#  'departure': 1,
#  'Dark': 6,
#  'Souls': 7,
#  'series': 5,
#  'games': 10,
#  'also': 9,
#  'made': 2,
#  'developers': 1,
#  'looked': 1,
#  'Tenchu': 3,
#  'inspiration': 2,
#  'praised': 11,
#  'critics': 2,
#  'complimented': 1,
#  'gameplay': 2,
#  'setting': 1,
#  'compared': 1,
#  'although': 1,
#  'opinions': 1,
#  'difficulty': 3,
#  'mixed': 2,
#  'nominated': 2,
#  'various': 2,
#  'awards': 2,
#  'several': 3,
#  'including': 2,
#  'Game': 5,
#  'Award': 1,
#  'Year': 1,
#  'sold': 3,
#  'five': 2,
#  'million': 3,
#  'copies': 3,
#  'July': 2,
#  'played': 2,
#  'third-person': 1,
#  'view': 1,
#  '1': 1,
#  '2': 2,
#  '3': 8,
#  'Compared': 1,
#  "'s": 29,
#  'features': 2,
#  'fewer': 1,
#  'role-playing': 1,
#  'elements': 3,
#  'lacking': 1,
#  'character': 5,
#  'creation': 1,
#  'ability': 2,
#  'level': 5,
#  'variety': 2,
#  'stats': 1,
#  'well': 1,
#  'multiplayer': 3,
#  '5': 1,
#  '6': 2,
#  'however': 2,
#  'include': 1,
#  'gear': 1,
#  'upgrading': 1,
#  'skill': 1,
#  'tree': 2,
#  'limited': 1,
#  'customization': 1,
#  'Rather': 1,
#  'attacking': 1,
#  'whittle': 1,
#  'enemy': 2,
#  'health': 3,
#  'points': 1,
#  'revolves': 1,
#  'around': 1,
#  'using': 3,
#  'katana': 1,
#  'attack': 3,
#  'posture': 3,
#  'balance': 1,
#  'instead': 4,
#  'eventually': 2,
#  'leads': 2,
#  'opening': 4,
#  'allows': 1,
#  'single': 1,
#  'killing': 1,
#  'blow': 1,
#  '7': 1,
#  'allowing': 1,
#  'players': 5,
#  'instantly': 1,
#  'eliminate': 1,
#  'enemies': 2,
#  'get': 1,
#  'range': 1,
#  'undetected': 1,
#  'In': 5,
#  'addition': 2,
#  'player': 6,
#  'use': 1,
#  'tools': 1,
#  'assist': 1,
#  'grappling': 4,
#  'hook': 5,
#  'If': 3,
#  'dies': 2,
#  'option': 1,
#  'revived': 1,
#  'spot': 1,
#  'resurrection': 2,
#  'power': 1,
#  'restored': 1,
#  'defeating': 3,
#  'respawning': 1,
#  'earlier': 1,
#  'checkpoints': 1,
#  'Following': 1,
#  'Isshin': 10,
#  'Ashina': 7,
#  'seized': 1,
#  'control': 1,
#  'land': 1,
#  'During': 1,
#  'time': 3,
#  'nameless': 1,
#  'orphan': 1,
#  'adopted': 1,
#  'wandering': 1,
#  'Owl': 6,
#  'named': 1,
#  'boy': 1,
#  'trained': 1,
#  'ways': 2,
#  'Two': 1,
#  'decades': 1,
#  'later': 1,
#  'brink': 1,
#  'collapse': 1,
#  'due': 2,
#  'elderly': 1,
#  'falling': 1,
#  'ill': 1,
#  'Interior': 2,
#  'Ministry': 2,
#  'group': 1,
#  'set': 1,
#  'unifying': 1,
#  'steadily': 1,
#  'closing': 1,
#  'Desperate': 1,
#  'save': 1,
#  'adoptive': 1,
#  'grandson': 2,
#  'Genichiro': 6,
#  'seeks': 2,
#  'immortal': 4,
#  'Divine': 4,
#  'Heir': 1,
#  'Kuro': 15,
#  'hopes': 1,
#  'Dragon': 7,
#  'Heritage': 6,
#  'blood': 1,
#  'army': 1,
#  'full-fledged': 1,
#  'personal': 1,
#  'bodyguard': 1,
#  'fights': 3,
#  'loses': 1,
#  'left': 2,
#  'arm': 2,
#  'However': 4,
#  'survives': 2,
#  'found': 2,
#  'retired': 1,
#  'Sculptor': 3,
#  'nurses': 1,
#  'back': 2,
#  'gifts': 1,
#  'prosthetic': 1,
#  'To': 1,
#  'rescue': 1,
#  'assaults': 1,
#  'Castle': 1,
#  'whilst': 1,
#  'forced': 2,
#  'confront': 1,
#  'past': 1,
#  'Three': 1,
#  'years': 1,
#  'ago': 1,
#  'birthplace': 1,
#  'Hirata': 2,
#  'estate': 2,
#  'raided': 1,
#  'bandits': 1,
#  'led': 1,
#  'former': 1,
#  'teacher': 1,
#  'Lady': 1,
#  'Butterfly': 1,
#  'able': 1,
#  'defeat': 1,
#  'stabbed': 1,
#  'unknown': 2,
#  'assailant': 2,
#  'survived': 1,
#  'Back': 1,
#  'present': 1,
#  'confronts': 1,
#  'defeats': 2,
#  'drinking': 1,
#  'artificial': 1,
#  'replication': 1,
#  'Rejuvenating': 2,
#  'Waters': 2,
#  'flees': 1,
#  'asks': 1,
#  'perform': 1,
#  'Immortal': 2,
#  'Severance': 2,
#  'ritual': 6,
#  'would': 3,
#  'result': 1,
#  'death': 1,
#  'prevent': 1,
#  'anyone': 1,
#  'fighting': 1,
#  'immortality': 2,
#  'reluctantly': 1,
#  'agrees': 1,
#  'sets': 1,
#  'collect': 2,
#  'necessary': 1,
#  'materials': 1,
#  'quest': 1,
#  'cross': 1,
#  'paths': 2,
#  'gives': 1,
#  'name': 2,
#  '``': 43,
#  'one-armed': 2,
#  'wolf': 2,
#  "''": 41,
#  'After': 2,
#  'collecting': 1,
#  'components': 1,
#  'confronted': 1,
#  'revealed': 3,
#  'back-stabbed': 1,
#  'reveals': 1,
#  'orders': 1,
#  'renounce': 1,
#  'loyalty': 1,
#  'sides': 1,
#  'fight': 1,
#  'doctor': 1,
#  'Emma': 2,
#  'Upon': 2,
#  'proceeds': 1,
#  'betray': 1,
#  'realizes': 1,
#  'corrupted': 1,
#  'bloodlust': 1,
#  'resulting': 1,
#  'Shura': 1,
#  'ending': 4,
#  'chosen': 1,
#  'kills': 1,
#  'enters': 1,
#  'Realm': 1,
#  'final': 4,
#  'material': 1,
#  'returning': 1,
#  'discovers': 1,
#  'succumbed': 1,
#  'illness': 1,
#  'castle': 1,
#  'finds': 1,
#  'Realizing': 1,
#  'lost': 1,
#  'sacrifices': 2,
#  'revive': 1,
#  'prime': 1,
#  'might': 1,
#  'restore': 1,
#  'honors': 1,
#  'wish': 1,
#  'three': 1,
#  'possible': 1,
#  'endings': 1,
#  'Performing': 1,
#  'results': 2,
#  'eponymous': 1,
#  'standard': 1,
#  'removed': 1,
#  'cost': 1,
#  'life': 1,
#  'Afterward': 1,
#  'like': 2,
#  'retires': 1,
#  'spends': 1,
#  'remainder': 1,
#  'days': 3,
#  'carving': 1,
#  'Buddha': 1,
#  'Statues': 1,
#  'Working': 1,
#  'find': 1,
#  'alternative': 1,
#  'way': 1,
#  'severing': 1,
#  'Purification': 1,
#  'Homecoming': 1,
#  'obtained': 1,
#  'helping': 1,
#  'Child': 2,
#  'body': 1,
#  'spirit': 1,
#  'lives': 1,
#  'inside': 1,
#  'goes': 1,
#  'journey': 1,
#  'return': 1,
#  'origin': 1,
#  'Development': 1,
#  'began': 1,
#  'late': 2,
#  '2015': 1,
#  'following': 1,
#  'completion': 1,
#  'Bloodborne': 3,
#  'downloadable': 1,
#  'content': 2,
#  'Old': 1,
#  'Hunters': 1,
#  '8': 1,
#  'directed': 1,
#  'previously': 1,
#  'worked': 1,
#  '9': 1,
#  'draws': 1,
#  'stealth-action': 1,
#  'partially': 1,
#  '10': 1,
#  'team': 2,
#  'initially': 2,
#  'considered': 1,
#  'developing': 1,
#  'sequel': 1,
#  'quickly': 1,
#  'outgrew': 1,
#  'concept': 1,
#  '11': 1,
#  'intended': 1,
#  'changes': 1,
#  'capture': 1,
#  'feel': 2,
#  'swords': 1,
#  'clashing': 1,
#  'fighters': 1,
#  'trying': 1,
#  'deliver': 1,
#  'fatal': 1,
#  'strike': 1,
#  'He': 3,
#  'created': 1,
#  'entirely': 1,
#  'single-player': 1,
#  'experience': 2,
#  'believed': 1,
#  'limitations': 1,
#  'avoid': 1,
#  'Despite': 1,
#  'taking': 1,
#  'real-world': 1,
#  'Japanese': 2,
#  'history': 2,
#  'historical': 1,
#  'people': 2,
#  'locations': 1,
#  'featured': 1,
#  '12': 1,
#  'via': 1,
#  'teaser': 2,
#  'trailer': 2,
#  'Awards': 3,
#  '2017': 1,
#  'December': 1,
#  'showing': 1,
#  'tagline': 1,
#  '13': 1,
#  'full': 2,
#  'title': 1,
#  'Microsoft': 1,
#  'press': 1,
#  'conference': 1,
#  'E3': 1,
#  '2018.The': 1,
#  'worldwide': 2,
#  'self-publishing': 1,
#  'Cube': 1,
#  'publishing': 1,
#  'Asia-Pacific': 1,
#  'region': 1,
#  '14': 1,
#  '15': 1,
#  'soundtrack': 2,
#  'composed': 1,
#  'Yuka': 1,
#  'Kitamura': 1,
#  '16': 1,
#  'contributions': 1,
#  'Noriyuki': 1,
#  'Asakura': 1,
#  '22': 2,
#  '17': 2,
#  'A': 2,
#  'collectors': 1,
#  'edition': 1,
#  'day': 2,
#  'included': 1,
#  'steelbook': 1,
#  'case': 1,
#  'figurine': 1,
#  'protagonist': 1,
#  'art': 1,
#  'book': 1,
#  'physical': 1,
#  'map': 1,
#  'world': 3,
#  'download': 1,
#  'code': 1,
#  'in-game': 1,
#  'coin': 1,
#  'replicas': 1,
#  'port': 1,
#  '18': 1,
#  'On': 2,
#  '31': 1,
#  'free': 1,
#  'update': 1,
#  'added': 1,
#  'cosmetics': 1,
#  'rush': 1,
#  'mode': 1,
#  '19': 1,
#  'word': 1,
#  'sekirō': 1,
#  '隻狼': 1,
#  'contraction': 1,
#  'sekiwan': 1,
#  'ōkami': 1,
#  '隻腕の狼': 1,
#  'translates': 1,
#  '20': 1,
#  'subtitle': 1,
#  'meant': 1,
#  'used': 2,
#  'slogan': 1,
#  'requested': 1,
#  'kept': 1,
#  '21': 1,
#  'According': 1,
#  'review': 3,
#  'aggregator': 1,
#  'Metacritic': 1,
#  'received': 1,
#  'universal': 1,
#  'acclaim': 1,
#  'versions': 1,
#  'generally': 1,
#  'favorable': 1,
#  'reviews': 1,
#  'version': 1,
#  '23': 1,
#  '24': 1,
#  'Many': 1,
#  'departing': 1,
#  'typical': 1,
#  'style': 1,
#  'similar': 1,
#  'Destructoid': 1,
#  'Chris': 1,
#  'Carter': 3,
#  'described': 1,
#  'open': 1,
#  'akin': 1,
#  'waltz': 1,
#  'could': 1,
#  'approached': 1,
#  'writing': 5,
#  'choices': 1,
#  '25': 1,
#  'Brandin': 1,
#  'Tyrell': 4,
#  'IGN': 1,
#  'focus': 1,
#  'split-second': 1,
#  'swordsmanship': 2,
#  'despite': 1,
#  'fact': 1,
#  'veteran': 1,
#  'timing-based': 1,
#  'lock-on': 1,
#  'strikes': 2,
#  'slashes': 1,
#  'familiar': 2,
#  'sense': 3,
#  'safety': 1,
#  'caused': 1,
#  'refreshing': 1,
#  '32': 1,
#  'PC': 2,
#  'Gamer': 2,
#  'journalist': 1,
#  'Tom': 2,
#  'Senior': 3,
#  'called': 1,
#  'beautiful': 1,
#  'system': 2,
#  'chipping': 1,
#  'bars': 1,
#  'keels': 1,
#  'overwhelm': 1,
#  'bar': 1,
#  'perfect': 1,
#  'parries': 1,
#  'appears': 1,
#  'finish': 1,
#  'deathblow': 1,
#  '37': 1,
#  'stated': 1,
#  'catharsis': 1,
#  'beating': 1,
#  'great': 1,
#  'focuses': 1,
#  'emotion': 1,
#  'one': 2,
#  'split': 1,
#  'second': 1,
#  'website': 1,
#  'GameSpot': 2,
#  'Tamoor': 1,
#  'Hussain': 3,
#  'wrote': 6,
#  'rewrites': 1,
#  'rules': 1,
#  'engagement': 1,
#  'stating': 1,
#  'previous': 2,
#  'demanded': 1,
#  'quick': 1,
#  'decision-making': 1,
#  'pushes': 1,
#  'demands': 1,
#  'ever': 2,
#  'Reviewers': 1,
#  'mechanic': 1,
#  'calling': 3,
#  'genius': 1,
#  'options': 1,
#  'gave': 1,
#  'freedom': 1,
#  'without': 2,
#  'descending': 1,
#  'frustration': 1,
#  'design': 3,
#  'Particular': 1,
#  'given': 1,
#  'increased': 1,
#  'verticality': 1,
#  'dedicated': 1,
#  'jump': 1,
#  'button': 2,
#  'sends': 1,
#  'ripples': 1,
#  'throughout': 1,
#  'Soulsborne': 2,
#  'characters': 1,
#  'felt': 1,
#  'rooted': 1,
#  'firmly': 1,
#  'ground': 1,
#  'trudged': 1,
#  'hallways': 1,
#  'slowly': 1,
#  'climbed': 1,
#  'ladders': 1,
#  'permission': 1,
#  'much': 1,
#  'vertical': 2,
#  'provided': 1,
#  'cases': 1,
#  'challenging': 1,
#  'standpoint': 1,
#  'large': 1,
#  'separate': 1,
#  'zones': 1,
#  'rather': 1,
#  'huge': 1,
#  'connected': 1,
#  'many': 1,
#  'secrets': 2,
#  'hidden': 2,
#  'critical': 1,
#  'path': 1,
#  'often': 1,
#  'reached': 2,
#  'excellent': 1,
#  'lets': 1,
#  'vault': 1,
#  'branches': 1,
#  'rooftops': 1,
#  'levels': 1,
#  'buildings': 1,
#  'placed': 1,
#  'together': 1,
#  'encourage': 1,
#  'reconnaissance': 1,
#  'roofs': 1,
#  'almost': 1,
#  'touching': 1,
#  'leap': 1,
#  'scope': 1,
#  'angles': 1,
#  'branching': 1,
#  'creating': 1,
#  'satisfying': 1,
#  'feeling': 1,
#  'venturing': 1,
#  'emerging': 1,
#  '30': 1,
#  'Reaction': 1,
#  'lack': 2,
#  'online': 2,
#  'Several': 3,
#  'reviewers': 2,
#  'noted': 2,
#  'allowed': 1,
#  'pause': 1,
#  'missed': 1,
#  'small': 1,
#  'notes': 1,
#  'others': 1,
#  'alerting': 1,
#  'imminent': 1,
#  'threats': 1,
#  'vague': 1,
#  'danger': 1,
#  'lurks': 1,
#  'behind': 2,
#  'form': 1,
#  'invading': 1,
#  'defined': 1,
#  'playing': 1,
#  'noticed': 1,
#  'PvP': 1,
#  'seem': 1,
#  'ed': 1,
#  'waste': 1,
#  'skill-based': 1,
#  'argued': 3,
#  'parrying': 1,
#  'blocking': 1,
#  'mechanics': 1,
#  'suited': 2,
#  'play': 1,
#  'Similarly': 1,
#  'high': 1,
#  'polarised': 1,
#  'journalists': 2,
#  'brutal': 1,
#  'spectacular': 1,
#  'punishes': 1,
#  'missteps': 1,
#  'certain': 1,
#  'temperament': 1,
#  'specific': 1,
#  'slightly': 1,
#  'masochistic': 1,
#  'taste': 1,
#  'victory': 1,
#  'intense': 1,
#  'gratifying': 1,
#  'steep': 1,
#  'curve': 1,
#  'mastering': 1,
#  'somewhat': 1,
#  'easier': 2,
#  'predecessors': 1,
#  'still': 1,
#  'providing': 1,
#  'greatest': 1,
#  'swordsman': 1,
#  'lived': 1,
#  'tough': 2,
#  'victories': 1,
#  'Don': 1,
#  'Rowe': 1,
#  'Spinoff': 1,
#  'infuriating': 1,
#  'fun': 1,
#  'six': 1,
#  'hours': 1,
#  '38': 1,
#  'modders': 1,
#  'managed': 1,
#  'develop': 1,
#  'mods': 1,
#  'make': 1,
#  'changing': 1,
#  'speed': 1,
#  'relative': 1,
#  '39': 1,
#  'James': 1,
#  'Davenport': 1,
#  'said': 1,
#  'difficult': 1,
#  'beat': 1,
#  'help': 1,
#  'software': 1,
#  '40': 1,
#  'release': 2,
#  'drew': 1,
#  '108,000': 1,
#  'concurrent': 2,
#  'Steam': 3,
#  'highest': 2,
#  'launched': 1,
#  'January–March': 1,
#  'third': 1,
#  'platform': 2,
#  'Monster': 1,
#  'Hunter': 1,
#  'World': 1,
#  'III': 1,
#  '41': 1,
#  '42': 1,
#  'Later': 1,
#  '125,000': 1,
#  '43': 1,
#  'debut': 1,
#  'week': 1,
#  'topped': 1,
#  'UK': 1,
#  'EMEAA': 1,
#  'Europe': 1,
#  'Middle': 1,
#  'East': 1,
#  'Africa': 1,
#  'Asia': 1,
#  'charts': 1,
#  'surpassing': 1,
#  'Clancy': 1,
#  'Division': 1,
#  '44': 1,
#  '45': 1,
#  '46': 1,
#  'debuted': 1,
#  'first': 1,
#  '157,548': 1,
#  'retail': 1,
#  'weekend': 1,
#  '47': 1,
#  'Within': 1,
#  'ten': 1,
#  'two': 1,
#  'rose': 1,
#  '48': 1,
#  '49': 1,
#  'year': 1,
#  '50': 1,
#  'editors': 1,
#  '51': 1,
#  'fans': 1,
#  '52': 1}

# %%
# Normalizing the values of our word_frequencies dictionary

max_value = max(word_frequecies.values())

for k, v in word_frequecies.items():
    word_frequecies[k] = v / max_value

# %%
# Normalized dictionary

word_frequecies
# Out:
# {'Sekiro': 0.6511627906976745,
#  'Shadows': 0.11627906976744186,
#  'Die': 0.11627906976744186,
#  'Twice': 0.11627906976744186,
#  '2019': 0.13953488372093023,
#  'action-adventure': 0.046511627906976744,
#  'game': 0.8604651162790697,
#  'developed': 0.046511627906976744,
#  'FromSoftware': 0.18604651162790697,
#  'published': 0.06976744186046512,
#  'Activision': 0.06976744186046512,
#  'The': 0.5116279069767442,
#  'follows': 0.023255813953488372,
#  'shinobi': 0.13953488372093023,
#  'known': 0.11627906976744186,
#  'Wolf': 0.3023255813953488,
#  'attempts': 0.023255813953488372,
#  'take': 0.023255813953488372,
#  'revenge': 0.023255813953488372,
#  'samurai': 0.023255813953488372,
#  'clan': 0.046511627906976744,
#  'attacked': 0.023255813953488372,
#  'kidnapped': 0.023255813953488372,
#  'lord': 0.023255813953488372,
#  'It': 0.09302325581395349,
#  'released': 0.13953488372093023,
#  'PlayStation': 0.06976744186046512,
#  '4': 0.11627906976744186,
#  'Windows': 0.06976744186046512,
#  'Xbox': 0.06976744186046512,
#  'One': 0.06976744186046512,
#  'March': 0.06976744186046512,
#  'Stadia': 0.046511627906976744,
#  'October': 0.046511627906976744,
#  '2020': 0.11627906976744186,
#  'Gameplay': 0.023255813953488372,
#  'focused': 0.023255813953488372,
#  'stealth': 0.06976744186046512,
#  'exploration': 0.09302325581395349,
#  'combat': 0.2558139534883721,
#  'particular': 0.023255813953488372,
#  'emphasis': 0.06976744186046512,
#  'boss': 0.09302325581395349,
#  'battles': 0.046511627906976744,
#  'takes': 0.046511627906976744,
#  'place': 0.06976744186046512,
#  'fictionalized': 0.023255813953488372,
#  'Japan': 0.09302325581395349,
#  'Sengoku': 0.06976744186046512,
#  'period': 0.06976744186046512,
#  'makes': 0.023255813953488372,
#  'strong': 0.023255813953488372,
#  'references': 0.023255813953488372,
#  'Buddhist': 0.023255813953488372,
#  'mythology': 0.023255813953488372,
#  'philosophy': 0.023255813953488372,
#  'While': 0.046511627906976744,
#  'making': 0.046511627906976744,
#  'lead': 0.023255813953488372,
#  'director': 0.023255813953488372,
#  'Hidetaka': 0.046511627906976744,
#  'Miyazaki': 0.06976744186046512,
#  'wanted': 0.046511627906976744,
#  'create': 0.06976744186046512,
#  'new': 0.16279069767441862,
#  'intellectual': 0.023255813953488372,
#  'property': 0.023255813953488372,
#  'IP': 0.023255813953488372,
#  'marked': 0.023255813953488372,
#  'departure': 0.023255813953488372,
#  '39': 0.023255813953488372,
#  'James': 0.023255813953488372,
#  'Davenport': 0.023255813953488372,
#  'said': 0.023255813953488372,
#  'difficult': 0.023255813953488372,
#  'beat': 0.023255813953488372,
#  'help': 0.023255813953488372,
#  'software': 0.023255813953488372,
#  '40': 0.023255813953488372,
#  'release': 0.046511627906976744,
#  'drew': 0.023255813953488372,
#  '108,000': 0.023255813953488372,
#  'concurrent': 0.046511627906976744,
#  'Steam': 0.06976744186046512,
#  'highest': 0.046511627906976744,
#  'launched': 0.023255813953488372,
#  'January–March': 0.023255813953488372,
#  'third': 0.023255813953488372,
#  'platform': 0.046511627906976744,
#  'Monster': 0.023255813953488372,
#  'Hunter': 0.023255813953488372,
#  'World': 0.023255813953488372,
#  'III': 0.023255813953488372,
#  '41': 0.023255813953488372,
#  '42': 0.023255813953488372,
#  'Later': 0.023255813953488372,
#  '125,000': 0.023255813953488372,
#  '43': 0.023255813953488372,
#  'debut': 0.023255813953488372,
#  'week': 0.023255813953488372,
#  'topped': 0.023255813953488372,
#  'UK': 0.023255813953488372,
#  'EMEAA': 0.023255813953488372,
#  'Europe': 0.023255813953488372,
#  'Middle': 0.023255813953488372,
#  'East': 0.023255813953488372,
#  'Africa': 0.023255813953488372,
#  'Asia': 0.023255813953488372,
#  'charts': 0.023255813953488372,
#  'surpassing': 0.023255813953488372,
#  'Clancy': 0.023255813953488372,
#  'Division': 0.023255813953488372,
#  '44': 0.023255813953488372,
#  '45': 0.023255813953488372,
#  '46': 0.023255813953488372,
#  'debuted': 0.023255813953488372,
#  'first': 0.023255813953488372,
#  '157,548': 0.023255813953488372,
#  'retail': 0.023255813953488372,
#  'weekend': 0.023255813953488372,
#  '47': 0.023255813953488372,
#  'Within': 0.023255813953488372,
#  'ten': 0.023255813953488372,
#  'two': 0.023255813953488372,
#  'rose': 0.023255813953488372,
#  '48': 0.023255813953488372,
#  '49': 0.023255813953488372,
#  'year': 0.023255813953488372,
#  '50': 0.023255813953488372,
#  'editors': 0.023255813953488372,
#  '51': 0.023255813953488372,
#  'fans': 0.023255813953488372,
#  '52': 0.023255813953488372}

# %%
# Tokenizing the article into a sentences

sentences = nltk.sent_tokenize(article_content)
sentences
# Out:
# ['\nSekiro: Shadows Die Twice[a] is a 2019 action-adventure game developed by FromSoftware and published by Activision.',
#  'The game follows a shinobi known as Wolf as he attempts to take revenge on a samurai clan who attacked him and kidnapped his lord.',
#  'It was released for PlayStation 4, Windows, and Xbox One in March 2019 and for Stadia in October 2020.',
#  'Gameplay is focused on stealth, exploration, and combat, with a particular emphasis on boss battles.',
#  'The game takes place in a fictionalized Japan during the Sengoku period and makes strong references to Buddhist mythology and philosophy.',
#  'While making the game, lead director Hidetaka Miyazaki wanted to create a new intellectual property (IP) that marked a departure from the Dark Souls series of games also made by FromSoftware.',
#  'The developers looked to games such as the Tenchu series for inspiration.',
#  'Sekiro was praised by critics, who complimented its gameplay and setting, and compared it to the Dark Souls games, although opinions on its difficulty were mixed.',
#  'It was nominated for various awards and won several, including The Game Award for Game of the Year.',
#  'The game sold over five million copies by July 2020.',
#  'Sekiro: Shadows Die Twice is an action-adventure game played from a third-person view.',
#  "[1][2][3][4] Compared to FromSoftware's Dark Souls series, the game features fewer role-playing elements, lacking character creation and the ability to level up a variety of stats, as well as having no multiplayer elements.",
#  '[3][4][5][6] It does, however, include gear upgrading, a skill tree, and limited ability customization.',
#  "Rather than attacking to whittle an enemy's health points, combat in Sekiro revolves around using a katana to attack their posture and balance instead, which eventually leads to an opening that allows for a single killing blow.",
#  '[3][7]\nThe game also features stealth elements, allowing players to instantly eliminate some enemies if they can get in range undetected.',
#  '[3] In addition, the player character can use various tools to assist with combat and exploration, such as a grappling hook.',
#  '[3] If the player character dies, they have the option of being revived on the spot if they have resurrection power, which is restored by defeating enemies, instead of respawning at earlier checkpoints.',
#  '[3]\nFollowing the Sengoku period, Isshin Ashina seized control of the land of Ashina.',
#  'During this time, a nameless orphan is adopted by the wandering shinobi known as Owl, who named the boy Wolf, and trained him in the ways of the shinobi.',
#  'Two decades later, Ashina is on the brink of collapse due to the now elderly Isshin falling ill and the Interior Ministry, a group set on unifying Japan, steadily closing in.',
#  "Desperate to save his clan, Isshin's adoptive grandson Genichiro seeks the immortal Divine Heir Kuro in hopes of using the Dragon Heritage in his blood to create an immortal army.",
#  "Wolf, now a full-fledged shinobi and Kuro's personal bodyguard, fights Genichiro but loses both Kuro and his left arm.",
#  'However, being immortal himself, Wolf survives and is found by a retired shinobi known as the Sculptor.',
#  'The Sculptor nurses Wolf back to health and gifts him a prosthetic arm.',
#  "To rescue Kuro, Wolf assaults Ashina Castle whilst being forced to confront his own past; Three years ago, Kuro's birthplace, the Hirata estate, was raided by bandits led by Wolf's former teacher, Lady Butterfly.",
#  'While Wolf was able to defeat her, he was then stabbed in the back by an unknown assailant, but survived after Kuro made him immortal using the Dragon Heritage.',
#  'Back in the present, Wolf once again confronts Genichiro and this time, defeats him.',
#  'However, Genichiro survives by drinking an artificial replication of the Dragon Heritage known as the Rejuvenating Waters and flees.',
#  "Kuro asks Wolf to perform the Immortal Severance ritual, which would result in Kuro's death and prevent anyone from fighting over his immortality.",
#  'Wolf reluctantly agrees and sets out to collect the necessary materials for the ritual.',
#  'Wolf\'s quest leads him to cross paths with Isshin, who gives him a new name: Sekiro, the "one-armed wolf".',
#  'After collecting all the components for the ritual, Sekiro is confronted by Owl, who is revealed to be the assailant who back-stabbed Sekiro at the Hirata estate.',
#  'Owl reveals he also seeks the Dragon Heritage and orders Sekiro to renounce his loyalty to Kuro.',
#  "If Sekiro sides with Owl, he is forced to fight Isshin's doctor, Emma, and Isshin himself.",
#  'Upon defeating them, Sekiro proceeds to betray Owl while Kuro realizes he has been corrupted by bloodlust, resulting in the "Shura" ending.',
#  'If Kuro is chosen, Sekiro fights and kills Owl.',
#  'Sekiro then enters the Divine Realm to collect the final material for the ritual.',
#  'Upon returning to Ashina, Sekiro discovers Isshin has succumbed to his illness and that the castle is under attack by the Interior Ministry.',
#  'Sekiro eventually finds Kuro under attack by Genichiro, who he defeats once again.',
#  'Realizing Ashina is lost, Genichiro sacrifices himself in a ritual to revive Isshin in his prime so that he might restore Ashina.',
#  "Isshin honors his grandson's wish and fights Sekiro.",
#  'After defeating Isshin, there are three possible endings.',
#  "Performing the Immortal Severance ritual results in the eponymous standard ending, where the Dragon Heritage is removed at the cost of Kuro's life.",
#  'Afterward, like the Sculptor before him, Sekiro retires as a shinobi and spends the remainder of his days carving Buddha Statues.',
#  'Working with Emma to find an alternative way of severing immortality results in the Purification ending, where Sekiro sacrifices himself instead of Kuro.',
#  "The final ending, Dragon's Homecoming, is obtained by helping a character known as the Divine Child of the Rejuvenating Waters.",
#  "Kuro's body dies, but his spirit lives on inside the Divine Child, who goes on a journey with Sekiro to return the Dragon Heritage to its origin place.",
#  "Development of Sekiro began in late 2015 following the completion of Bloodborne's downloadable content, The Old Hunters.",
#  '[8] It was directed by Hidetaka Miyazaki, who had previously worked on the Dark Souls series and Bloodborne.',
#  '[9] Sekiro draws inspiration from the Tenchu series of stealth-action games that were partially developed and published by FromSoftware.',
#  '[10] The team initially considered developing the game as a sequel to Tenchu; however, it quickly outgrew the concept.',
#  '[11] Miyazaki intended the combat changes to capture the feel of "swords clashing", with fighters trying to create an opening to deliver the fatal strike.',
#  '[3] He and the team also created the game to be an entirely single-player experience, as they believed multiplayer to have limitations they wanted to avoid.',
#  '[6] Despite the game taking place during the Sengoku period of real-world Japanese history, no historical people or locations are featured in the game.',
#  '[12]\nThe game was revealed via a teaser trailer at The Game Awards 2017 in December, showing the tagline "Shadows Die Twice".',
#  "[13] The game's full title was revealed to be Sekiro: Shadows Die Twice during Microsoft's press conference at E3 2018.The game was published by Activision worldwide, with FromSoftware self-publishing it in Japan and Cube Game publishing in the Asia-Pacific region.",
#  "[14][15] Sekiro's soundtrack was composed by Yuka Kitamura,[16] with some contributions from Noriyuki Asakura.",
#  'The game was released for PlayStation 4, Windows, and Xbox One on 22 March 2019.',
#  "[17] A collectors edition was also released the same day, and included a steelbook case, a figurine of the protagonist, an art book, a physical map of the game's world, a download code for the soundtrack, and in-game coin replicas.",
#  '[17] A port for Stadia was released in late 2020.',
#  '[18] On 31 October 2020, a free update was released that added new content to the game, such as new cosmetics for Wolf and a boss rush game mode.',
#  '[19]\nThe word "sekirō" (隻狼) is a contraction of "sekiwan no ōkami" (隻腕の狼), which translates as "one-armed wolf.',
#  '"[20] The subtitle "Shadows Die Twice" was initially meant to be used as a slogan for the teaser trailer until Activision requested it be kept for the final name.',
#  '[3][21]\nAccording to review aggregator Metacritic, Sekiro received "universal acclaim" for the PlayStation 4 and Xbox One versions, and "generally favorable" reviews for the Windows version.',
#  "[22][23][24] Many critics praised the game's combat for departing from the typical style of FromSoftware's other similar games.",
#  'In a review for Destructoid, Chris Carter described open combat as "akin to a waltz" and praised the variety of ways the combat could be approached, writing that players had more choices than in Dark Souls or Bloodborne.',
#  '[25] Brandin Tyrell from IGN praised the game\'s focus on "split-second swordsmanship", and despite the fact that "to any Souls veteran, Sekiro\'s timing-based lock-on combat of strikes and slashes is familiar", the game\'s "sense of safety" caused the combat to feel "refreshing and new".',
#  '[32] PC Gamer journalist Tom Senior called the combat "beautiful" and praised the posture system, writing that "instead of chipping down health bars until the enemy keels over, you overwhelm their posture bar with strikes and perfect parries until an opening appears, and then finish with a deathblow".',
#  '[37] He stated that the system takes "the catharsis" of beating a great boss and "focuses all that emotion into one split second".',
#  'In a review for website GameSpot, Tamoor Hussain wrote that the game "rewrites the rules of engagement", stating that, while previous FromSoftware games demanded quick decision-making, Sekiro "pushes these demands further" than ever before.',
#  'Reviewers also praised the resurrection mechanic, with Carter calling it "genius", and the stealth options, which gave the player freedom without descending into frustration.',
#  'The level design was also praised.',
#  'Particular emphasis was given to the increased verticality the player had due to the addition of the grappling hook and a dedicated jump button.',
#  'Tyrell wrote that the grappling hook "sends ripples throughout the gameplay", writing that "where all previous Soulsborne characters felt rooted firmly to the ground as they trudged down hallways and slowly climbed ladders, Sekiro\'s level design has permission to be much more vertical".',
#  'Carter wrote that the hook provided "a more vertical and in some cases more challenging level design from an exploration standpoint".',
#  'Senior wrote that the game used "large but separate zones rather than a huge connected world", but praised the "many secrets hidden just off the critical path, often reached with the excellent grappling hook, which lets you vault between tree branches and rooftops".',
#  'The levels themselves were also praised, with Hussain writing that "buildings are placed together to encourage exploration and reconnaissance, with roofs almost touching so that you can leap between them and scope out all angles", with the branching paths "creating that satisfying feeling of venturing into the unknown and then emerging into the familiar".',
#  '[30]\nReaction to the lack of online multiplayer was mixed.',
#  'Several reviewers noted that this allowed the game to have a full pause button, which was praised.',
#  'However, Tyrell noted that he "missed the small notes left by others in the world alerting me to imminent threats or hidden secrets, or that vague sense that danger lurks behind me in the form of an invading player" that defined the experience of playing "Soulsborne" games.',
#  'He also noticed the "lack of PvP battles, which seem[ed] like a waste of the new emphasis on skill-based swordsmanship", and argued that the parrying and blocking mechanics would have suited online play.',
#  "Similarly to other FromSoftware games, the game's high level of difficulty polarised players and journalists.",
#  'Several reviewers praised the difficulty, with Senior calling it "brutal" but "spectacular".',
#  'Hussain wrote that the game "punishes you for missteps" and was "suited for people of a certain temperament and with a very specific, slightly masochistic taste in games", but argued that victory was "intense" and "gratifying".',
#  'Tyrell wrote that the combat had a "steep curve to mastering it" but argued it was "somewhat easier than its predecessors", while still providing the sense of being "the greatest swordsman that ever lived" after tough victories.',
#  'However, several journalists found it to be too tough, with Don Rowe from The Spinoff calling it "infuriating", and writing that he was not having fun after six hours with the game.',
#  "[38] Several days after the game was released, modders managed to develop mods which would make the game easier by changing the speed of the player's character relative to the game.",
#  "[39] James Davenport of PC Gamer said that the game's final boss was too difficult for him to beat without the help of the software.",
#  "[40]\nOn release day, Sekiro drew over 108,000 concurrent players on Steam, the highest for a new game launched during January–March 2019, and the third highest of any Japanese game in the platform's history, behind only Monster Hunter: World and Dark Souls III.",
#  '[41][42] Later in March, it had reached over 125,000 concurrent players on Steam, making it one of the most played games on the platform at the time.',
#  "[43] In its debut week, Sekiro topped both the UK and EMEAA (Europe, Middle East, Africa, Asia) charts, surpassing Tom Clancy's The Division 2.",
#  '[44][45][46] In Japan, the game debuted at first with 157,548 retail copies sold in its opening weekend.',
#  '[47] Within ten days of its release, over two\xa0million copies were sold worldwide, which rose to over five million by July 2020.',
#  '[48][49]\nThe game was nominated for and won several awards, including game of the year at The Game Awards 2019,[50] by editors of GameSpot,[51] and by fans in the 2019 Steam Awards.',
#  '[52]']

# %%
sentence_weights = {}
for sent in sentences:
    for key_words in word_frequecies:
        if key_words in sent:
            value = word_frequecies.get(key_words, 0)
            if sent in sentence_weights:
                sentence_weights[sent] += value
            else:
                sentence_weights[sent] = value

# %%
sentence_weights
# Out:
# {'\nSekiro: Shadows Die Twice[a] is a 2019 action-adventure game developed by FromSoftware and published by Activision.': 2.651162790697675,
#  'The game follows a shinobi known as Wolf as he attempts to take revenge on a samurai clan who attacked him and kidnapped his lord.': 2.2558139534883725,
#  'It was released for PlayStation 4, Windows, and Xbox One in March 2019 and for Stadia in October 2020.': 1.3023255813953494,
#  'Gameplay is focused on stealth, exploration, and combat, with a particular emphasis on boss battles.': 0.9767441860465118,
#  'The game takes place in a fictionalized Japan during the Sengoku period and makes strong references to Buddhist mythology and philosophy.': 1.9534883720930234,
#  'While making the game, lead director Hidetaka Miyazaki wanted to create a new intellectual property (IP) that marked a departure from the Dark Souls series of games also made by FromSoftware.': 2.6744186046511635,
#  'The developers looked to games such as the Tenchu series for inspiration.': 1.930232558139535,
#  'Sekiro was praised by critics, who complimented its gameplay and setting, and compared it to the Dark Souls games, although opinions on its difficulty were mixed.': 2.7209302325581404,
#  'It was nominated for various awards and won several, including The Game Award for Game of the Year.': 1.1395348837209303,
#  'The game sold over five million copies by July 2020.': 1.8837209302325582,
#  'Sekiro: Shadows Die Twice is an action-adventure game played from a third-person view.': 2.0697674418604652,
#  "[1][2][3][4] Compared to FromSoftware's Dark Souls series, the game features fewer role-playing elements, lacking character creation and the ability to level up a variety of stats, as well as having no multiplayer elements.": 3.4418604651162803,
#  '[3][4][5][6] It does, however, include gear upgrading, a skill tree, and limited ability customization.': 0.8372093023255817,
#  "Rather than attacking to whittle an enemy's health points, combat in Sekiro revolves around using a katana to attack their posture and balance instead, which eventually leads to an opening that allows for a single killing blow.": 2.534883720930234,
#  '[3][7]\nThe game also features stealth elements, allowing players to instantly eliminate some enemies if they can get in range undetected.': 2.4651162790697674,
#  '[3] In addition, the player character can use various tools to assist with combat and exploration, such as a grappling hook.': 1.302325581395349,
#  '[3] If the player character dies, they have the option of being revived on the spot if they have resurrection power, which is restored by defeating enemies, instead of respawning at earlier checkpoints.': 1.1395348837209307,
#  '[3]\nFollowing the Sengoku period, Isshin Ashina seized control of the land of Ashina.': 0.8837209302325583,
#  'During this time, a nameless orphan is adopted by the wandering shinobi known as Owl, who named the boy Wolf, and trained him in the ways of the shinobi.': 1.093023255813954,
#  'Two decades later, Ashina is on the brink of collapse due to the now elderly Isshin falling ill and the Interior Ministry, a group set on unifying Japan, steadily closing in.': 1.1395348837209307,
#  "Desperate to save his clan, Isshin's adoptive grandson Genichiro seeks the immortal Divine Heir Kuro in hopes of using the Dragon Heritage in his blood to create an immortal army.": 2.465116279069768,
#  "Wolf, now a full-fledged shinobi and Kuro's personal bodyguard, fights Genichiro but loses both Kuro and his left arm.": 2.0000000000000004,
#  'However, being immortal himself, Wolf survives and is found by a retired shinobi known as the Sculptor.': 1.0,
#  'The Sculptor nurses Wolf back to health and gifts him a prosthetic arm.': 1.116279069767442,
#  "To rescue Kuro, Wolf assaults Ashina Castle whilst being forced to confront his own past; Three years ago, Kuro's birthplace, the Hirata estate, was raided by bandits led by Wolf's former teacher, Lady Butterfly.": 2.232558139534885,
#  'While Wolf was able to defeat her, he was then stabbed in the back by an unknown assailant, but survived after Kuro made him immortal using the Dragon Heritage.': 1.674418604651163,
#  'Back in the present, Wolf once again confronts Genichiro and this time, defeats him.': 0.674418604651163,
#  'However, Genichiro survives by drinking an artificial replication of the Dragon Heritage known as the Rejuvenating Waters and flees.': 1.046511627906977,
#  "Kuro asks Wolf to perform the Immortal Severance ritual, which would result in Kuro's death and prevent anyone from fighting over his immortality.": 2.0697674418604657,
#  'Wolf reluctantly agrees and sets out to collect the necessary materials for the ritual.': 0.6511627906976745,
#  'Wolf\'s quest leads him to cross paths with Isshin, who gives him a new name: Sekiro, the "one-armed wolf".': 2.4883720930232567,
#  'After collecting all the components for the ritual, Sekiro is confronted by Owl, who is revealed to be the assailant who back-stabbed Sekiro at the Hirata estate.': 1.5581395348837215,
#  'Owl reveals he also seeks the Dragon Heritage and orders Sekiro to renounce his loyalty to Kuro.': 1.8837209302325584,
#  "If Sekiro sides with Owl, he is forced to fight Isshin's doctor, Emma, and Isshin himself.": 1.9534883720930236,
#  'Upon defeating them, Sekiro proceeds to betray Owl while Kuro realizes he has been corrupted by bloodlust, resulting in the "Shura" ending.': 1.6046511627906983,
#  'If Kuro is chosen, Sekiro fights and kills Owl.': 1.3720930232558142,
#  'Sekiro then enters the Divine Realm to collect the final material for the ritual.': 1.0930232558139537,
#  'Upon returning to Ashina, Sekiro discovers Isshin has succumbed to his illness and that the castle is under attack by the Interior Ministry.': 1.6046511627906985,
#  'Sekiro eventually finds Kuro under attack by Genichiro, who he defeats once again.': 1.3720930232558142,
#  'Realizing Ashina is lost, Genichiro sacrifices himself in a ritual to revive Isshin in his prime so that he might restore Ashina.': 0.9069767441860468,
#  "Isshin honors his grandson's wish and fights Sekiro.": 1.7441860465116281,
#  'After defeating Isshin, there are three possible endings.': 0.5813953488372093,
#  "Performing the Immortal Severance ritual results in the eponymous standard ending, where the Dragon Heritage is removed at the cost of Kuro's life.": 2.0465116279069773,
#  'Afterward, like the Sculptor before him, Sekiro retires as a shinobi and spends the remainder of his days carving Buddha Statues.': 1.2790697674418607,
#  'Working with Emma to find an alternative way of severing immortality results in the Purification ending, where Sekiro sacrifices himself instead of Kuro.': 1.6744186046511633,
#  "The final ending, Dragon's Homecoming, is obtained by helping a character known as the Divine Child of the Rejuvenating Waters.": 2.1395348837209305,
#  "Kuro's body dies, but his spirit lives on inside the Divine Child, who goes on a journey with Sekiro to return the Dragon Heritage to its origin place.": 2.5116279069767447,
#  "Development of Sekiro began in late 2015 following the completion of Bloodborne's downloadable content, The Old Hunters.": 2.418604651162792,
#  '[8] It was directed by Hidetaka Miyazaki, who had previously worked on the Dark Souls series and Bloodborne.': 0.86046511627907,
#  '[9] Sekiro draws inspiration from the Tenchu series of stealth-action games that were partially developed and published by FromSoftware.': 2.5116279069767447,
#  '[10] The team initially considered developing the game as a sequel to Tenchu; however, it quickly outgrew the concept.': 1.8837209302325588,
#  '[11] Miyazaki intended the combat changes to capture the feel of "swords clashing", with fighters trying to create an opening to deliver the fatal strike.': 0.9302325581395355,
#  '[3] He and the team also created the game to be an entirely single-player experience, as they believed multiplayer to have limitations they wanted to avoid.': 1.9534883720930234,
#  '[6] Despite the game taking place during the Sengoku period of real-world Japanese history, no historical people or locations are featured in the game.': 1.604651162790698,
#  '[12]\nThe game was revealed via a teaser trailer at The Game Awards 2017 in December, showing the tagline "Shadows Die Twice".': 2.4883720930232567,
#  "[13] The game's full title was revealed to be Sekiro: Shadows Die Twice during Microsoft's press conference at E3 2018.The game was published by Activision worldwide, with FromSoftware self-publishing it in Japan and Cube Game publishing in the Asia-Pacific region.": 4.534883720930234,
#  "[14][15] Sekiro's soundtrack was composed by Yuka Kitamura,[16] with some contributions from Noriyuki Asakura.": 1.8604651162790704,
#  'The game was released for PlayStation 4, Windows, and Xbox One on 22 March 2019.': 2.418604651162791,
#  "[17] A collectors edition was also released the same day, and included a steelbook case, a figurine of the protagonist, an art book, a physical map of the game's world, a download code for the soundtrack, and in-game coin replicas.": 2.720930232558141,
#  '[17] A port for Stadia was released in late 2020.': 0.6511627906976745,
#  '[18] On 31 October 2020, a free update was released that added new content to the game, such as new cosmetics for Wolf and a boss rush game mode.': 2.395348837209303,
#  '[19]\nThe word "sekirō" (隻狼) is a contraction of "sekiwan no ōkami" (隻腕の狼), which translates as "one-armed wolf.': 1.0232558139534889,
#  '"[20] The subtitle "Shadows Die Twice" was initially meant to be used as a slogan for the teaser trailer until Activision requested it be kept for the final name.': 1.5813953488372101,
#  '[3][21]\nAccording to review aggregator Metacritic, Sekiro received "universal acclaim" for the PlayStation 4 and Xbox One versions, and "generally favorable" reviews for the Windows version.': 1.8139534883720938,
#  "[22][23][24] Many critics praised the game's combat for departing from the typical style of FromSoftware's other similar games.": 3.116279069767442,
#  'In a review for Destructoid, Chris Carter described open combat as "akin to a waltz" and praised the variety of ways the combat could be approached, writing that players had more choices than in Dark Souls or Bloodborne.': 1.9302325581395354,
#  '[25] Brandin Tyrell from IGN praised the game\'s focus on "split-second swordsmanship", and despite the fact that "to any Souls veteran, Sekiro\'s timing-based lock-on combat of strikes and slashes is familiar", the game\'s "sense of safety" caused the combat to feel "refreshing and new".': 4.000000000000002,
#  '[32] PC Gamer journalist Tom Senior called the combat "beautiful" and praised the posture system, writing that "instead of chipping down health bars until the enemy keels over, you overwhelm their posture bar with strikes and perfect parries until an opening appears, and then finish with a deathblow".': 2.139534883720931,
#  '[37] He stated that the system takes "the catharsis" of beating a great boss and "focuses all that emotion into one split second".': 0.8372093023255818,
#  'In a review for website GameSpot, Tamoor Hussain wrote that the game "rewrites the rules of engagement", stating that, while previous FromSoftware games demanded quick decision-making, Sekiro "pushes these demands further" than ever before.': 2.9534883720930245,
#  'Reviewers also praised the resurrection mechanic, with Carter calling it "genius", and the stealth options, which gave the player freedom without descending into frustration.': 1.3255813953488378,
#  'The level design was also praised.': 1.186046511627907,
#  'Particular emphasis was given to the increased verticality the player had due to the addition of the grappling hook and a dedicated jump button.': 0.8139534883720934,
#  'Tyrell wrote that the grappling hook "sends ripples throughout the gameplay", writing that "where all previous Soulsborne characters felt rooted firmly to the ground as they trudged down hallways and slowly climbed ladders, Sekiro\'s level design has permission to be much more vertical".': 3.860465116279072,
#  'Carter wrote that the hook provided "a more vertical and in some cases more challenging level design from an exploration standpoint".': 0.8139534883720931,
#  'Senior wrote that the game used "large but separate zones rather than a huge connected world", but praised the "many secrets hidden just off the critical path, often reached with the excellent grappling hook, which lets you vault between tree branches and rooftops".': 2.30232558139535,
#  'The levels themselves were also praised, with Hussain writing that "buildings are placed together to encourage exploration and reconnaissance, with roofs almost touching so that you can leap between them and scope out all angles", with the branching paths "creating that satisfying feeling of venturing into the unknown and then emerging into the familiar".': 2.2325581395348846,
#  '[30]\nReaction to the lack of online multiplayer was mixed.': 0.627906976744186,
#  'Several reviewers noted that this allowed the game to have a full pause button, which was praised.': 1.604651162790698,
#  'However, Tyrell noted that he "missed the small notes left by others in the world alerting me to imminent threats or hidden secrets, or that vague sense that danger lurks behind me in the form of an invading player" that defined the experience of playing "Soulsborne" games.': 2.4651162790697683,
#  'He also noticed the "lack of PvP battles, which seem[ed] like a waste of the new emphasis on skill-based swordsmanship", and argued that the parrying and blocking mechanics would have suited online play.': 1.3023255813953494,
#  "Similarly to other FromSoftware games, the game's high level of difficulty polarised players and journalists.": 2.6046511627906983,
#  'Several reviewers praised the difficulty, with Senior calling it "brutal" but "spectacular".': 0.8139534883720932,
#  'Hussain wrote that the game "punishes you for missteps" and was "suited for people of a certain temperament and with a very specific, slightly masochistic taste in games", but argued that victory was "intense" and "gratifying".': 1.7674418604651168,
#  'Tyrell wrote that the combat had a "steep curve to mastering it" but argued it was "somewhat easier than its predecessors", while still providing the sense of being "the greatest swordsman that ever lived" after tough victories.': 1.1395348837209307,
#  'However, several journalists found it to be too tough, with Don Rowe from The Spinoff calling it "infuriating", and writing that he was not having fun after six hours with the game.': 2.0930232558139537,
#  "[38] Several days after the game was released, modders managed to develop mods which would make the game easier by changing the speed of the player's character relative to the game.": 2.7906976744186056,
#  "[39] James Davenport of PC Gamer said that the game's final boss was too difficult for him to beat without the help of the software.": 2.395348837209303,
#  "[40]\nOn release day, Sekiro drew over 108,000 concurrent players on Steam, the highest for a new game launched during January–March 2019, and the third highest of any Japanese game in the platform's history, behind only Monster Hunter: World and Dark Souls III.": 4.372093023255815,
#  '[41][42] Later in March, it had reached over 125,000 concurrent players on Steam, making it one of the most played games on the platform at the time.': 2.3255813953488382,
#  "[43] In its debut week, Sekiro topped both the UK and EMEAA (Europe, Middle East, Africa, Asia) charts, surpassing Tom Clancy's The Division 2.": 2.813953488372094,
#  '[44][45][46] In Japan, the game debuted at first with 157,548 retail copies sold in its opening weekend.': 1.8837209302325586,
#  '[47] Within ten days of its release, over two\xa0million copies were sold worldwide, which rose to over five million by July 2020.': 1.0465116279069768,
#  '[48][49]\nThe game was nominated for and won several awards, including game of the year at The Game Awards 2019,[50] by editors of GameSpot,[51] and by fans in the 2019 Steam Awards.': 2.674418604651164,
#  '[52]': 0.09302325581395349}

# %%
select_lenght = int(len(sentences) * 0.30)

summary = nlargest(select_lenght, sentence_weights, key=sentence_weights.get)

# %%
# Rearranging the summary so, we can have structured sentences

new_summary = []
for sent in sentences:
    if sent in summary:
        new_summary.append(sent)
        
final_summary = " ".join([word for word in new_summary])

# %%
print(final_summary)
# Out:
# Sekiro: Shadows Die Twice[a] is a 2019 action-adventure game developed by FromSoftware and published by Activision. While making the game, lead director Hidetaka Miyazaki wanted to create a new intellectual property (IP) that marked a departure from the Dark Souls series of games also made by FromSoftware. Sekiro was praised by critics, who complimented its gameplay and setting, and compared it to the Dark Souls games, although opinions on its difficulty were mixed. [1][2][3][4] Compared to FromSoftware's Dark Souls series, the game features fewer role-playing elements, lacking character creation and the ability to level up a variety of stats, as well as having no multiplayer elements. Rather than attacking to whittle an enemy's health points, combat in Sekiro revolves around using a katana to attack their posture and balance instead, which eventually leads to an opening that allows for a single killing blow. [3][7]
# The game also features stealth elements, allowing players to instantly eliminate some enemies if they can get in range undetected. Desperate to save his clan, Isshin's adoptive grandson Genichiro seeks the immortal Divine Heir Kuro in hopes of using the Dragon Heritage in his blood to create an immortal army. Wolf's quest leads him to cross paths with Isshin, who gives him a new name: Sekiro, the "one-armed wolf". Kuro's body dies, but his spirit lives on inside the Divine Child, who goes on a journey with Sekiro to return the Dragon Heritage to its origin place. Development of Sekiro began in late 2015 following the completion of Bloodborne's downloadable content, The Old Hunters. [9] Sekiro draws inspiration from the Tenchu series of stealth-action games that were partially developed and published by FromSoftware. [12]
# The game was revealed via a teaser trailer at The Game Awards 2017 in December, showing the tagline "Shadows Die Twice". [13] The game's full title was revealed to be Sekiro: Shadows Die Twice during Microsoft's press conference at E3 2018.The game was published by Activision worldwide, with FromSoftware self-publishing it in Japan and Cube Game publishing in the Asia-Pacific region. The game was released for PlayStation 4, Windows, and Xbox One on 22 March 2019. [17] A collectors edition was also released the same day, and included a steelbook case, a figurine of the protagonist, an art book, a physical map of the game's world, a download code for the soundtrack, and in-game coin replicas. [18] On 31 October 2020, a free update was released that added new content to the game, such as new cosmetics for Wolf and a boss rush game mode. [22][23][24] Many critics praised the game's combat for departing from the typical style of FromSoftware's other similar games. [25] Brandin Tyrell from IGN praised the game's focus on "split-second swordsmanship", and despite the fact that "to any Souls veteran, Sekiro's timing-based lock-on combat of strikes and slashes is familiar", the game's "sense of safety" caused the combat to feel "refreshing and new". In a review for website GameSpot, Tamoor Hussain wrote that the game "rewrites the rules of engagement", stating that, while previous FromSoftware games demanded quick decision-making, Sekiro "pushes these demands further" than ever before. Tyrell wrote that the grappling hook "sends ripples throughout the gameplay", writing that "where all previous Soulsborne characters felt rooted firmly to the ground as they trudged down hallways and slowly climbed ladders, Sekiro's level design has permission to be much more vertical". However, Tyrell noted that he "missed the small notes left by others in the world alerting me to imminent threats or hidden secrets, or that vague sense that danger lurks behind me in the form of an invading player" that defined the experience of playing "Soulsborne" games. Similarly to other FromSoftware games, the game's high level of difficulty polarised players and journalists. [38] Several days after the game was released, modders managed to develop mods which would make the game easier by changing the speed of the player's character relative to the game. [39] James Davenport of PC Gamer said that the game's final boss was too difficult for him to beat without the help of the software. [40]
# On release day, Sekiro drew over 108,000 concurrent players on Steam, the highest for a new game launched during January–March 2019, and the third highest of any Japanese game in the platform's history, behind only Monster Hunter: World and Dark Souls III. [41][42] Later in March, it had reached over 125,000 concurrent players on Steam, making it one of the most played games on the platform at the time. [43] In its debut week, Sekiro topped both the UK and EMEAA (Europe, Middle East, Africa, Asia) charts, surpassing Tom Clancy's The Division 2. [48][49]
# The game was nominated for and won several awards, including game of the year at The Game Awards 2019,[50] by editors of GameSpot,[51] and by fans in the 2019 Steam Awards.

# %% [markdown]
# ### Creating the function

# %%
def SummarizeText():
    link = input("Please paste/type the wikipedia link: \n")
    percent = float(input("\nHow short do you want to summarize the page? (0.0 - 1.0): \n"))
    content = requests.get(link).text
    article = BeautifulSoup(content, 'lxml')
    article_content = ""
    for paragraph in article.find_all('p'):
        article_content += paragraph.text
        
    punctuation_ = punctuation + '\n'
    stop_words = stopwords.words('english')
    text_ = [word for word in nltk.word_tokenize(article_content) if word not in punctuation_ and word not in stop_words]
    word_frequecies = {}
    for word in text_:
        if word in word_frequecies:
            word_frequecies[word] += 1
        else:
            word_frequecies[word] = 1
    
    max_value = max(word_frequecies.values())
    
    for k, v in word_frequecies.items():
        word_frequecies[k] = v / max_value
        
    sentences = nltk.sent_tokenize(article_content)
    
    sentence_weights = {}
    for sent in sentences:
        for key_words in word_frequecies:
            if key_words in sent:
                value = word_frequecies.get(key_words, 0)
                if sent in sentence_weights:
                    sentence_weights[sent] += value
                else:
                    sentence_weights[sent] = value
                    
    select_lenght = int(len(sentences)*percent)
    
    summary = nlargest(select_lenght, sentence_weights, key=sentence_weights.get)
    
    new_summary = []
    for sent in sentences:
        if sent in summary:
            new_summary.append(sent)
        
    final_summary = " ".join([word for word in new_summary])
    
    print("\n\n"," "*50, "SUMMARIZED TEXT")
    print("="*120)
    print(final_summary)
    print("\n","="*120)

# %%
SummarizeText()
# Out:
# Please paste/type the wikipedia link:
# https://en.wikipedia.org/wiki/Sekiro:_Shadows_Die_Twice
#
# How short do you want to summarize the page? (0.0 - 1.0):
# 0.3
#
#
#                                                     SUMMARIZED TEXT
# ========================================================================================================================
#
# Sekiro: Shadows Die Twice[a] is a 2019 action-adventure game developed by FromSoftware and published by Activision. While making the game, lead director Hidetaka Miyazaki wanted to create a new intellectual property (IP) that marked a departure from the Dark Souls series of games also made by FromSoftware. Sekiro was praised by critics, who complimented its gameplay and setting, and compared it to the Dark Souls games, although opinions on its difficulty were mixed. [1][2][3][4] Compared to FromSoftware's Dark Souls series, the game features fewer role-playing elements, lacking character creation and the ability to level up a variety of stats, as well as having no multiplayer elements. Rather than attacking to whittle an enemy's health points, combat in Sekiro revolves around using a katana to attack their posture and balance instead, which eventually leads to an opening that allows for a single killing blow. [3][7]
# The game also features stealth elements, allowing players to instantly eliminate some enemies if they can get in range undetected. Desperate to save his clan, Isshin's adoptive grandson Genichiro seeks the immortal Divine Heir Kuro in hopes of using the Dragon Heritage in his blood to create an immortal army. Wolf's quest leads him to cross paths with Isshin, who gives him a new name: Sekiro, the "one-armed wolf". Kuro's body dies, but his spirit lives on inside the Divine Child, who goes on a journey with Sekiro to return the Dragon Heritage to its origin place. Development of Sekiro began in late 2015 following the completion of Bloodborne's downloadable content, The Old Hunters. [9] Sekiro draws inspiration from the Tenchu series of stealth-action games that were partially developed and published by FromSoftware. [12]
# The game was revealed via a teaser trailer at The Game Awards 2017 in December, showing the tagline "Shadows Die Twice". [13] The game's full title was revealed to be Sekiro: Shadows Die Twice during Microsoft's press conference at E3 2018.The game was published by Activision worldwide, with FromSoftware self-publishing it in Japan and Cube Game publishing in the Asia-Pacific region. The game was released for PlayStation 4, Windows, and Xbox One on 22 March 2019. [17] A collectors edition was also released the same day, and included a steelbook case, a figurine of the protagonist, an art book, a physical map of the game's world, a download code for the soundtrack, and in-game coin replicas. [18] On 31 October 2020, a free update was released that added new content to the game, such as new cosmetics for Wolf and a boss rush game mode. [22][23][24] Many critics praised the game's combat for departing from the typical style of FromSoftware's other similar games. [25] Brandin Tyrell from IGN praised the game's focus on "split-second swordsmanship", and despite the fact that "to any Souls veteran, Sekiro's timing-based lock-on combat of strikes and slashes is familiar", the game's "sense of safety" caused the combat to feel "refreshing and new". In a review for website GameSpot, Tamoor Hussain wrote that the game "rewrites the rules of engagement", stating that, while previous FromSoftware games demanded quick decision-making, Sekiro "pushes these demands further" than ever before. Tyrell wrote that the grappling hook "sends ripples throughout the gameplay", writing that "where all previous Soulsborne characters felt rooted firmly to the ground as they trudged down hallways and slowly climbed ladders, Sekiro's level design has permission to be much more vertical". However, Tyrell noted that he "missed the small notes left by others in the world alerting me to imminent threats or hidden secrets, or that vague sense that danger lurks behind me in the form of an invading player" that defined the experience of playing "Soulsborne" games. Similarly to other FromSoftware games, the game's high level of difficulty polarised players and journalists. [38] Several days after the game was released, modders managed to develop mods which would make the game easier by changing the speed of the player's character relative to the game. [39] James Davenport of PC Gamer said that the game's final boss was too difficult for him to beat without the help of the software. [40]
# On release day, Sekiro drew over 108,000 concurrent players on Steam, the highest for a new game launched during January–March 2019, and the third highest of any Japanese game in the platform's history, behind only Monster Hunter: World and Dark Souls III. [41][42] Later in March, it had reached over 125,000 concurrent players on Steam, making it one of the most played games on the platform at the time. [43] In its debut week, Sekiro topped both the UK and EMEAA (Europe, Middle East, Africa, Asia) charts, surpassing Tom Clancy's The Division 2. [48][49]
# The game was nominated for and won several awards, including game of the year at The Game Awards 2019,[50] by editors of GameSpot,[51] and by fans in the 2019 Steam Awards.
#
#  ========================================================================================================================
